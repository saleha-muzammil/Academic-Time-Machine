# %% [markdown]
# ### 1 *Importing Necessary Libraries*

# %%
import pandas as pd
import numpy as np
import folium
from folium import GeoJson
from folium.plugins import MarkerCluster
import geopandas as gpd

# %% [markdown]
# ### 2 *Loading Dataset and Basic Preprocessing*

# %%
data=pd.read_csv("crimes_dataset.csv")
data.columns = data.columns.str.lower().str.replace(' ', '_')
data['block_location']=data['block_location'].str.replace('\n', ' ', regex=True)

# %%
data.head(3)
# Out:
#     id      caseno            offense            cvlegend  cvdow  \
# 0  0.0  17091420.0      BURGLARY AUTO  BURGLARY - VEHICLE    0.0
# 1  1.0  17020462.0  THEFT FROM PERSON             LARCENY    4.0
# 2  2.0  17050275.0      BURGLARY AUTO  BURGLARY - VEHICLE    4.0
#
#                                       block_location             blkaddr  \
# 0  2500 LE CONTE AVE Berkeley, CA (37.876965, -12...   2500 LE CONTE AVE
# 1  2200 SHATTUCK AVE Berkeley, CA (37.869363, -12...   2200 SHATTUCK AVE
# 2  200 UNIVERSITY AVE Berkeley, CA (37.865491, -1...  200 UNIVERSITY AVE
#
#        city state       day        lat         lon         timestamp
# 0  Berkeley    CA    Sunday  37.876965 -122.260544   23/07/2017 6:00
# 1  Berkeley    CA  Thursday  37.869363 -122.268028   13/04/2017 8:45
# 2  Berkeley    CA  Thursday  37.865491 -122.310065  24/08/2017 18:30

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5508 entries, 0 to 5507
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2000 non-null   float64
#  1   caseno          2000 non-null   float64
#  2   offense         2000 non-null   object
#  3   cvlegend        2000 non-null   object
#  4   cvdow           2000 non-null   float64
#  5   block_location  2000 non-null   object
#  6   blkaddr         1992 non-null   object
#  7   city            2000 non-null   object
#  8   state           2000 non-null   object
#  9   day             2000 non-null   object
#  10  lat             1908 non-null   float64
#  11  lon             1908 non-null   float64
#  12  timestamp       2000 non-null   object
# dtypes: float64(5), object(8)
# memory usage: 559.5+ KB

# %%
data.describe(include="all")
# Out:
#                  id        caseno        offense cvlegend        cvdow  \
# count   2000.000000  2.000000e+03           2000     2000  2000.000000
# unique          NaN           NaN             28       21          NaN
# top             NaN           NaN  BURGLARY AUTO  LARCENY          NaN
# freq            NaN           NaN            379      427          NaN
# mean     999.500000  1.704434e+07            NaN      NaN     3.094000
# std      577.494589  2.674710e+04            NaN      NaN     1.971321
# min        0.000000  1.700023e+07            NaN      NaN     0.000000
# 25%      499.750000  1.702349e+07            NaN      NaN     1.000000
# 50%      999.500000  1.703707e+07            NaN      NaN     3.000000
# 75%     1499.250000  1.704907e+07            NaN      NaN     5.000000
# max     1999.000000  1.709167e+07            NaN      NaN     6.000000
#
#                                            block_location            blkaddr  \
# count                                                2000               1992
# unique                                               1013               1012
# top     2100 SHATTUCK AVE Berkeley, CA (37.871167, -12...  2100 SHATTUCK AVE
# freq                                                   36                 36
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# min                                                   NaN                NaN
# 25%                                                   NaN                NaN
# 50%                                                   NaN                NaN
# 75%                                                   NaN                NaN
# max                                                   NaN                NaN
#
#             city state     day          lat          lon         timestamp
# count       2000  2000    2000  1908.000000  1908.000000              2000
# unique         1     1       7          NaN          NaN              1905
# top     Berkeley    CA  Friday          NaN          NaN  21/08/2017 17:00
# freq        2000  2000     315          NaN          NaN                 4
# mean         NaN   NaN     NaN    37.868259  -122.275695               NaN
# std          NaN   NaN     NaN     0.010352     0.015878               NaN
# min          NaN   NaN     NaN    37.821533  -122.317566               NaN
# 25%          NaN   NaN     NaN    37.861991  -122.288543               NaN
# 50%          NaN   NaN     NaN    37.868164  -122.270706               NaN
# 75%          NaN   NaN     NaN    37.872989  -122.265050               NaN
# max          NaN   NaN     NaN    37.904331  -122.236429               NaN

# %% [markdown]
# ### Q1 *a*

# %%
print(f"Most Frequent Offense is \"{data['offense'].value_counts().idxmax()}\"")
print(f"With the frequency of {data['offense'].value_counts().max()}")
# Out:
# Most Frequent Offense is "BURGLARY AUTO"
# With the frequency of 379

# %% [markdown]
# ### Q1 b
# **(CVDOW is the Label Encoded Format of DAY, using DAY instead of CVDOW)**

# %%
data.groupby('day')['offense'].count()
# Out:
# day
# Friday       315
# Monday       287
# Saturday     287
# Sunday       245
# Thursday     298
# Tuesday      292
# Wednesday    276
# Name: offense, dtype: int64

# %%
print(f"Day with most crimes is \"{data.groupby('day')['offense'].count().idxmax()}\"")
print(f"With the frequency of {data.groupby('day')['offense'].count().max()}")
# Out:
# Day with most crimes is "Friday"
# With the frequency of 315

# %% [markdown]
# ### Q1 c

# %%
print(f"Location with most crimes is \"{data.groupby(['lat', 'lon'])['offense'].count().idxmax()}\"")
print(f"With the frequency of {data.groupby(['lat', 'lon'])['offense'].count().max()}")
# Out:
# Location with most crimes is "(37.871167, -122.268285)"
# With the frequency of 40

# %% [markdown]
# ### Q1 d

# %%
data['block_location'].value_counts()
# Out:
# 2100 SHATTUCK AVE Berkeley, CA (37.871167, -122.268285)                   36
# 2200 SHATTUCK AVE Berkeley, CA (37.869363, -122.268028)                   20
# 2300 TELEGRAPH AVE Berkeley, CA (37.868714, -122.259189)                  20
# 200 UNIVERSITY AVE Berkeley, CA (37.865491, -122.310065)                  17
# 1900 SHATTUCK AVE Berkeley, CA (37.873687, -122.268616)                   17
#                                                                           ..
# BANCROFT WAY &amp; ELLSWORTH ST Berkeley, CA (37.86814, -122.263736)       1
# 1100 OXFORD ST Berkeley, CA (37.88878, -122.267659)                        1
# FULTON STREET &amp; KITTREDGE ST Berkeley, CA (37.868706, -122.266279)     1
# CHANNING WAY &amp; WARRING ST Berkeley, CA (37.867919, -122.250841)        1
# 2700 STUART ST Berkeley, CA (37.859846, -122.253325)                       1
# Name: block_location, Length: 1013, dtype: int64

# %%
print(f"Blocks with most crimes is \"{data['block_location'].value_counts().idxmax()}\"")
print(f"With the frequency of {data['block_location'].value_counts().max()}")
# Out:
# Blocks with most crimes is "2100 SHATTUCK AVE Berkeley, CA (37.871167, -122.268285)"
# With the frequency of 36

# %% [markdown]
# ## Q2 Showing the Frequency Map
# Note: This data is plotted based on dropping nulls, it was a part of Q1, but was not carried there

# %%
m = folium.Map(location=[data['lat'].mean(), data['lon'].mean()], zoom_start=13)
marker_cluster = MarkerCluster().add_to(m)



for i, j in data.iterrows():
    if pd.notna(j['lat']) and pd.notna(j['lon']):
        t=f"Offense: {j['offense']}"
        folium.Marker([j['lat'], j['lon']], t).add_to(marker_cluster)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84a53b3fd41042711f1f6ff10d55b4d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84a53b3fd41042711f1f6ff10d55b4d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84a53b3fd41042711f1f6ff10d55b4d6 = L.map(
#                 &quot;map_84a53b3fd41042711f1f6ff10d55b4d6&quot;,
#                 {
#                     center: [37.86825855345912, -122.27569541981133],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ea096b32ffeab24453f316837eeae3f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_8ea096b32ffeab24453f316837eeae3f.addTo(map_84a53b3fd41042711f1f6ff10d55b4d6);
#
#             var marker_cluster_e92150b26b8dcd9a7d36546403adc32a = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_9dd9143c926b9bba85c0ad0a7c14e0aa = L.marker(
#                 [37.876965, -122.260544],
#                 {}
#             ).addTo(marker_cluster_e92150b26b8dcd9a7d36546403adc32a);
#
#
#         var popup_fa4c9fc41c7d323d802c52ebb0c2ec75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c840adc5dec575219731c507b213c13 = $(`&lt;div id=&quot;html_7c840adc5dec575219731c507b213c13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Offense: BURGLARY AUTO&lt;/div&gt;`)[0];
#                 popup_fa4c9fc41c7d323d802c52ebb0c2ec75.setContent(html_7c840adc5dec575219731c507b213c13);
#
#
#
#         marker_9dd9143c926b9bba85c0ad0a7c14e0aa.bindPopup(popup_fa4c9fc41c7d323d802c52ebb0c2ec75)
#         ;
#
#
#
#
#             var marker_ca2b2c098b9089f6b9188eafe580cb5d = L.marker(
#                 [37.869363, -122.268028],
#                 {}
#             ).addTo(marker_cluster_e92150b26b8dcd9a7d36546403adc32a);
#
#
#         var popup_733cd40d6a445b7ad85d66c8ae59b1fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19051ba37280f9a28ecda7c1aced8689 = $(`&lt;div id=&quot;html_19051ba37280f9a28ecda7c1aced8689&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Offense: THEFT FROM PERSON&lt;/div&gt;`)[0];
#                 popup_733cd40d6a445b7ad85d66c8ae59b1fe.setContent(html_19051ba37280f9a28ecda7c1aced8689);
#
#
#
#         marker_ca2b2c098b9089f6b9188eafe580cb5d.bindPopup(popup_733cd40d6a445b7ad85d66c8ae59b1fe)
#         ;
#
#
#
#
#             var marker_b1f0e0cab92f4846797d9df4b90a1f76 = L.marker(
#                 [37.865491, -122.310065],
#                 {}
#             ).addTo(marker_cluster_e92150b26b8dcd9a7d36546403adc32a);
#
#
#         var popup_a2d92bdc17000fe95b9330e6af3ca8af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc033047e3e20367eaacb6681d5a5ffb = $(`&lt;div id=&quot;html_dc033047e3e20367eaacb6681d5a5ffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Offense: BURGLARY AUTO&lt;/div&gt;`)[0];
#                 popup_a2d92bdc17000fe95b9330e6af3ca8af.setContent(html_dc033047e3e20367eaacb6681d5a5ffb);
#
#
#
#         marker_b1f0e0cab92f4846797d9df4b90a1f76.bindPopup(popup_a2d92bdc17000fe95b9330e6af3ca8af)
#         ;
#
#
#
#
#             var marker_cb9dff598da1cf679ecd7e0e47c3bbdd = L.marker(
#                 [37.869318, -122.296984],
#                 {}
#             ).addTo(marker_cluster_e92150b26b8dcd9a7d36546403adc32a);
#
#
#         var popup_4e4ec81fe2f3d8e7f03d09dee44fcf08 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_124034bd57681b917a262814c490e010 = $(`&lt;div id=&quot;html_124034bd57681b917a262814c490e010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Offense: GUN/WEAPON&lt;/div&gt;`)[0];
#                 popup_4e4ec81fe2f3d8e7f03d09dee44fcf08.setContent(html_124034bd57681b917a262814c490e010);
#
#
#
#         marker_cb9dff598da1cf679ecd7e0e47c3bbdd.bindPopup(popup_4e4ec81fe2f3d8e7f03d09dee44fcf08)
#         ;
#
#
#
#
#             var marker_7332724e32cb28f5e7232aec1523e3ed = L.marker(
#                 [37.854247, -122.24375],
#                 {}
#             ).addTo(marker_cluster_e
