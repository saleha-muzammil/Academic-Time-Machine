# %%
import random

class Board:
  def __init__(self, population):
    self.population = population
    self.coords=list()
    self.fitness=0
    for i in range(0,population):
      self.coords.append((random.randint(0,population)))

  def __lt__(self, other):
    return self.fitness > other.fitness

  def getCoords(self):
    return self.coords

  def setCoords(self, coords):
    self.coords=coords

  # valid attacking function must not count those previously counted
  def getAttackingTable(self):
    index=0
    attacking=list()

    for i in range(0, len(self.coords)):
      attacking.append(0)
      for j in range(i+1, len(self.coords)):
        #check if in same row
        if self.coords[i]==self.coords[j]:
          attacking[index]+=1
        #check if in same diagonal
        #comment out one diagonal to get response in decent time
        """or (self.coords[j]-j) == (self.coords[i]-i)"""
        if ((self.coords[i]+i) == (self.coords[j]+j) or (self.coords[j]-j) == (self.coords[i]-i)):
          attacking[index]+=1
      index+=1

    return attacking

  def generateFitness(self):
    size=len(self.coords)
    self.fitness=0
    attacking=self.getAttackingTable()

    # formula: summation(number of pieces being attacked by queen in columns ahead)
    for i in range(0,size):
      self.fitness+=(size - i - 1 - attacking[i])

    return self.fitness

  def getFitness(self):
    return self.fitness

  def populateChessBoard(self, chess_board):
    i=0
    coordinates=list()

    for coord in self.coords:
      chess_board[coord][i]='Q'
      coordinates.append((i, coord))
      i+=1

    return coordinates, chess_board


# Utility functions

def generateChessBoard(population):
  chessBoard=[]
  for i in range(0, population):
    row=[]
    for j in range(0, population):
      row.append('X')
    chessBoard.append(row)
  return chessBoard

def crossOver(coords1, coords2):
  res1=list()
  res2=list()

  cutoff=random.randint(2,len(coords1)-2)

  for i in range(len(coords1)):
    if i < cutoff:
      res1.append(coords2[i])
      res2.append(coords1[i])
    else:
      res1.append(coords1[i])
      res2.append(coords2[i])

  return res1, res2


def mutation(coords):
  index=random.randint(0,len(coords)-1)
  coords[index]=random.randint(0,len(coords)-1)

  return coords

def summation(population):
  val=0

  for i in range(population):
    val+=population-1-i

  return val  

def main():
  boards=list()
  fitnesses=list()
  maxFitness=0
  count=0
  totalFitness=0
  localFitness=0
  randomThreshold=0
  print("Input board size: ")
  population=int(input())
  for i in range(0,4):
    boards.append(Board(population))

  for board in boards:
    print("Coordinates:", board.getCoords())
    board.generateFitness()
    print("Fitness", board.getFitness())
    print("")

  while (maxFitness<summation(population)):
    count+=1
    print("Generation", count)
    print("")
    boards.sort()

    totalFitness=0
    for board in boards:
      board.generateFitness()
      totalFitness+=board.getFitness()

    # selecting top 1, top 2 and top 1, top 3 for crossover using Roulette Wheel
    # randomThreshold=random.randint(0, totalFitness)
    # localFitness=0
    # index=-1
    # while localFitness<randomThreshold:
    #   index+=1
    #   localFitness+=boards[index].getFitness()
    # coords1=boards[index].getCoords()

    # randomThreshold=random.randint(0, totalFitness)
    # localFitness=0
    # index=-1
    # while localFitness<randomThreshold:
    #   index+=1
    #   localFitness+=boards[index].getFitness()
    # coords2=boards[index].getCoords()
    # coords3=boards[index].getCoords()

    # randomThreshold=random.randint(0, totalFitness)
    # localFitness=0
    # index=-1
    # while localFitness<randomThreshold:
    #   index+=1
    #   localFitness+=boards[index].getFitness()
    # coords4=boards[index].getCoords()
    
    # selecting top 1, top 2 and top 1, top 3 for crossover 
    coords1, coords2 = boards[0].getCoords(), boards[1].getCoords()
    coords3, coords4 = boards[0].getCoords(), boards[2].getCoords()

    coords1, coords2 = crossOver(coords1, coords2)
    coords3, coords4 = crossOver(coords3, coords4)
    boards[0].setCoords(coords1)
    boards[1].setCoords(coords2)
    boards[2].setCoords(coords3)
    boards[3].setCoords(coords4)

    print("After Crossover")
    for board in boards:
      print("Coordinates:", board.getCoords())
      board.generateFitness()
      print("Fitness", board.getFitness())
      print("")

    boards[0].setCoords(mutation(coords1))
    boards[1].setCoords(mutation(coords2))
    boards[2].setCoords(mutation(coords3))
    boards[3].setCoords(mutation(coords4))

    print("After Mutation")
    for board in boards:
      print("Coordinates:", board.getCoords())
      board.generateFitness()
      print("Fitness", board.getFitness())
      print("")

    maxFitness=boards[0].getFitness()

  chessBoard=generateChessBoard(population)
  coordinates, chessBoard=boards[0].populateChessBoard(chessBoard)

  print("Generation", count)
  print("Ideal State Reached!")
  print("Coordinates:", coordinates)
  print("Attacking pairs:", boards[0].getAttackingTable())
  for row in chessBoard:
    print(row)
  print("")



if __name__ == "__main__":
  main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Coordinates: [0, 4, 2, 0, 2]
# Fitness 7
#
# Coordinates: [3, 0, 0, 1, 2]
# Fitness 6
#
# Generation 49
#
# After Crossover
# Coordinates: [0, 4, 4, 2, 2]
# Fitness 6
#
# Coordinates: [3, 0, 2, 0, 2]
# Fitness 7
#
# Coordinates: [3, 0, 4, 2, 2]
# Fitness 7
#
# Coordinates: [3, 0, 0, 1, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [4, 4, 4, 2, 2]
# Fitness 4
#
# Coordinates: [2, 0, 2, 0, 2]
# Fitness 6
#
# Coordinates: [1, 0, 4, 2, 2]
# Fitness 6
#
# Coordinates: [3, 0, 4, 1, 2]
# Fitness 8
#
# Generation 50
#
# After Crossover
# Coordinates: [2, 0, 4, 1, 2]
# Fitness 6
#
# Coordinates: [3, 0, 2, 0, 2]
# Fitness 7
#
# Coordinates: [1, 0, 4, 1, 2]
# Fitness 6
#
# Coordinates: [3, 0, 4, 2, 2]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 0, 4, 1, 2]
# Fitness 6
#
# Coordinates: [3, 0, 2, 4, 2]
# Fitness 9
#
# Coordinates: [1, 3, 4, 1, 2]
# Fitness 5
#
# Coordinates: [4, 0, 4, 2, 2]
# Fitness 6
#
# Generation 51
#
# After Crossover
# Coordinates: [2, 0, 4, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 2, 1, 2]
# Fitness 7
#
# Coordinates: [4, 0, 4, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 2, 2, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [2, 0, 4, 0, 2]
# Fitness 6
#
# Coordinates: [2, 0, 2, 1, 2]
# Fitness 5
#
# Coordinates: [4, 4, 4, 4, 2]
# Fitness 3
#
# Coordinates: [4, 0, 2, 2, 2]
# Fitness 5
#
# Generation 52
#
# After Crossover
# Coordinates: [2, 0, 4, 0, 2]
# Fitness 6
#
# Coordinates: [2, 0, 2, 1, 2]
# Fitness 5
#
# Coordinates: [4, 0, 2, 0, 2]
# Fitness 7
#
# Coordinates: [2, 0, 4, 2, 2]
# Fitness 4
#
# After Mutation
# Coordinates: [2, 1, 4, 0, 2]
# Fitness 6
#
# Coordinates: [2, 0, 4, 1, 2]
# Fitness 6
#
# Coordinates: [4, 4, 2, 0, 2]
# Fitness 7
#
# Coordinates: [2, 0, 2, 2, 2]
# Fitness 3
#
# Generation 53
#
# After Crossover
# Coordinates: [2, 1, 4, 0, 2]
# Fitness 6
#
# Coordinates: [4, 4, 2, 0, 2]
# Fitness 7
#
# Coordinates: [2, 0, 4, 0, 2]
# Fitness 6
#
# Coordinates: [4, 4, 2, 1, 2]
# Fitness 4
#
# After Mutation
# Coordinates: [2, 4, 4, 0, 2]
# Fitness 6
#
# Coordinates: [4, 4, 2, 0, 2]
# Fitness 7
#
# Coordinates: [2, 1, 4, 0, 2]
# Fitness 6
#
# Coordinates: [2, 4, 2, 1, 2]
# Fitness 5
#
# Generation 54
#
# After Crossover
# Coordinates: [2, 4, 2, 0, 2]
# Fitness 7
#
# Coordinates: [4, 4, 4, 0, 2]
# Fitness 6
#
# Coordinates: [2, 1, 2, 0, 2]
# Fitness 5
#
# Coordinates: [4, 4, 4, 0, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [2, 4, 2, 0, 2]
# Fitness 7
#
# Coordinates: [4, 2, 4, 0, 2]
# Fitness 6
#
# Coordinates: [2, 4, 2, 0, 2]
# Fitness 7
#
# Coordinates: [4, 4, 4, 0, 3]
# Fitness 7
#
# Generation 55
#
# After Crossover
# Coordinates: [2, 4, 2, 0, 2]
# Fitness 7
#
# Coordinates: [2, 4, 2, 0, 2]
# Fitness 7
#
# Coordinates: [4, 4, 2, 0, 2]
# Fitness 7
#
# Coordinates: [2, 4, 4, 0, 3]
# Fitness 8
#
# After Mutation
# Coordinates: [2, 1, 2, 0, 2]
# Fitness 5
#
# Coordinates: [2, 4, 2, 3, 2]
# Fitness 5
#
# Coordinates: [4, 4, 2, 1, 2]
# Fitness 4
#
# Coordinates: [2, 4, 0, 0, 3]
# Fitness 8
#
# Generation 56
#
# After Crossover
# Coordinates: [2, 1, 0, 0, 3]
# Fitness 6
#
# Coordinates: [2, 4, 2, 0, 2]
# Fitness 7
#
# Coordinates: [2, 4, 2, 0, 3]
# Fitness 9
#
# Coordinates: [2, 4, 0, 3, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [2, 1, 0, 0, 3]
# Fitness 6
#
# Coordinates: [2, 3, 2, 0, 2]
# Fitness 5
#
# Coordinates: [2, 1, 2, 0, 3]
# Fitness 7
#
# Coordinates: [1, 4, 0, 3, 2]
# Fitness 8
#
# Generation 57
#
# After Crossover
# Coordinates: [2, 1, 0, 3, 2]
# Fitness 3
#
# Coordinates: [1, 4, 2, 0, 3]
# Fitness 10
#
# Coordinates: [2, 1, 0, 3, 2]
# Fitness 3
#
# Coordinates: [1, 4, 0, 0, 3]
# Fitness 9
#
# After Mutation
# Coordinates: [2, 1, 0, 2, 2]
# Fitness 3
#
# Coordinates: [1, 4, 2, 0, 0]
# Fitness 8
#
# Coordinates: [2, 1, 0, 0, 2]
# Fitness 4
#
# Coordinates: [1, 4, 0, 2, 3]
# Fitness 8
#
# Generation 58
#
# After Crossover
# Coordinates: [1, 4, 2, 0, 0]
# Fitness 8
#
# Coordinates: [1, 4, 0, 2, 3]
# Fitness 8
#
# Coordinates: [2, 1, 0, 0, 0]
# Fitness 4
#
# Coordinates: [1, 4, 2, 0, 2]
# Fitness 9
#
# After Mutation
# Coordinates: [1, 4, 2, 0, 0]
# Fitness 8
#
# Coordinates: [1, 4, 0, 3, 3]
# Fitness 9
#
# Coordinates: [2, 1, 0, 1, 0]
# Fitness 3
#
# Coordinates: [2, 4, 2, 0, 2]
# Fitness 7
#
# Generation 59
#
# After Crossover
# Coordinates: [1, 4, 2, 3, 3]
# Fitness 8
#
# Coordinates: [1, 4, 0, 0, 0]
# Fitness 7
#
# Coordinates: [2, 4, 2, 3, 3]
# Fitness 7
#
# Coordinates: [1, 4, 0, 0, 2]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 4, 2, 4, 3]
# Fitness 7
#
# Coordinates: [1, 4, 1, 0, 0]
# Fitness 7
#
# Coordinates: [2, 0, 2, 3, 3]
# Fitness 6
#
# Coordinates: [1, 2, 0, 0, 2]
# Fitness 5
#
# Generation 60
#
# After Crossover
# Coordinates: [1, 4, 1, 4, 3]
# Fitness 5
#
# Coordinates: [1, 4, 2, 0, 0]
# Fitness 8
#
# Coordinates: [2, 0, 2, 4, 3]
# Fitness 7
#
# Coordinates: [1, 4, 2, 3, 3]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 4, 3, 4, 3]
# Fitness 3
#
# Coordinates: [1, 4, 2, 1, 0]
# Fitness 6
#
# Coordinates: [2, 2, 2, 4, 3]
# Fitness 5
#
# Coordinates: [1, 3, 2, 3, 3]
# Fitness 5
#
# Generation 61
#
# After Crossover
# Coordinates: [2, 2, 2, 1, 0]
# Fitness 4
#
# Coordinates: [1, 4, 2, 4, 3]
# Fitness 7
#
# Coordinates: [1, 3, 2, 1, 0]
# Fitness 3
#
# Coordinates: [1, 4, 2, 3, 3]
# Fitness 8
#
# After Mutation
# Coordinates: [2, 2, 0, 1, 0]
# Fitness 5
#
# Coordinates: [1, 4, 2, 4, 4]
# Fitness 5
#
# Coordinates: [1, 3, 3, 1, 0]
# Fitness 4
#
# Coordinates: [1, 4, 1, 3, 3]
# Fitness 7
#
# Generation 62
#
# After Crossover
# Coordinates: [2, 2, 0, 3, 3]
# Fitness 7
#
# Coordinates: [1, 4, 1, 1, 0]
# Fitness 6
#
# Coordinates: [1, 4, 1, 3, 3]
# Fitness 7
#
# Coordinates: [1, 4, 2, 4, 4]
# Fitness 5
#
# After Mutation
# Coordinates: [1, 2, 0, 3, 3]
# Fitness 8
#
# Coordinates: [1, 4, 1, 2, 0]
# Fitness 7
#
# Coordinates: [1, 4, 1, 3, 3]
# Fitness 7
#
# Coordinates: [1, 4, 2, 4, 4]
# Fitness 5
#
# Generation 63
#
# After Crossover
# Coordinates: [1, 4, 1, 3, 3]
# Fitness 7
#
# Coordinates: [1, 2, 0, 2, 0]
# Fitness 7
#
# Coordinates: [1, 4, 0, 3, 3]
# Fitness 9
#
# Coordinates: [1, 2, 1, 3, 3]
# Fitness 5
#
# After Mutation
# Coordinates: [3, 4, 1, 3, 3]
# Fitness 4
#
# Coordinates: [1, 2, 0, 2, 0]
# Fitness 7
#
# Coordinates: [1, 2, 0, 3, 3]
# Fitness 8
#
# Coordinates: [1, 2, 1, 2, 3]
# Fitness 3
#
# Generation 64
#
# After Crossover
# Coordinates: [1, 2, 0, 3, 3]
# Fitness 8
#
# Coordinates: [1, 2, 0, 2, 0]
# Fitness 7
#
# Coordinates: [3, 4, 0, 3, 3]
# Fitness 6
#
# Coordinates: [1, 2, 1, 3, 3]
# Fitness 5
#
# After Mutation
# Coordinates: [1, 2, 0, 2, 3]
# Fitness 7
#
# Coordinates: [1, 2, 0, 2, 0]
# Fitness 7
#
# Coordinates: [3, 1, 0, 3, 3]
# Fitness 5
#
# Coordinates: [1, 4, 1, 3, 3]
# Fitness 7
#
# Generation 65
#
# After Crossover
# Coordinates: [1, 2, 0, 2, 3]
# Fitness 7
#
# Coordinates: [1, 2, 0, 2, 0]
# Fitness 7
#
# Coordinates: [1, 4, 1, 2, 3]
# Fitness 5
#
# Coordinates: [1, 2, 0, 3, 3]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 2, 0, 2, 3]
# Fitness 7
#
# Coordinates: [0, 2, 0, 2, 0]
# Fitness 6
#
# Coordinates: [1, 0, 1, 2, 3]
# Fitness 2
#
# Coordinates: [1, 2, 0, 2, 3]
# Fitness 7
#
# Generation 66
#
# After Crossover
# Coordinates: [1, 2, 0, 2, 3]
# Fitness 7
#
# Coordinates: [1, 2, 0, 2, 3]
# Fitness 7
#
# Coordinates: [0, 2, 0, 2, 3]
# Fitness 7
#
# Coordinates: [1, 2, 0, 2, 0]
# Fitness 7
#
# After Mutation
# Coordinates: [3, 2, 0, 2, 3]
# Fitness 6
#
# Coordinates: [1, 2, 0, 2, 2]
# Fitness 5
#
# Coordinates: [0, 2, 0, 2, 0]
# Fitness 6
#
# Coordinates: [1, 2, 0, 1, 0]
# Fitness 5
#
# Generation 67
#
# After Crossover
# Coordinates: [0, 2, 0, 2, 3]
# Fitness 7
#
# Coordinates: [3, 2, 0, 2, 0]
# Fitness 7
#
# Coordinates: [1, 2, 0, 2, 3]
# Fitness 7
#
# Coordinates: [3, 2, 0, 2, 2]
# Fitness 5
#
# After Mutation
# Coordinates: [0, 2, 0, 1, 3]
# Fitness 8
#
# Coordinates: [3, 2, 0, 2, 2]
# Fitness 5
#
# Coordinates: [1, 2, 0, 2, 2]
# Fitness 5
#
# Coordinates: [3, 2, 0, 2, 2]
# Fitness 5
#
# Generation 68
#
# After Crossover
# Coordinates: [3, 2, 0, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 0, 2, 2]
# Fitness 5
#
# Coordinates: [1, 2, 0, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 0, 2, 2]
# Fitness 5
#
# After Mutation
# Coordinates: [3, 2, 2, 1, 3]
# Fitness 6
#
# Coordinates: [0, 2, 2, 2, 2]
# Fitness 3
#
# Coordinates: [3, 2, 0, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 0, 3, 2]
# Fitness 5
#
# Generation 69
#
# After Crossover
# Coordinates: [3, 2, 2, 1, 3]
# Fitness 6
#
# Coordinates: [3, 2, 0, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 0, 1, 3]
# Fitness 8
#
# Coordinates: [3, 2, 0, 3, 2]
# Fitness 5
#
# After Mutation
# Coordinates: [3, 2, 4, 1, 3]
# Fitness 8
#
# Coordinates: [2, 2, 0, 1, 3]
# Fitness 7
#
# Coordinates: [4, 2, 0, 1, 3]
# Fitness 8
#
# Coordinates: [3, 2, 3, 3, 2]
# Fitness 3
#
# Generation 70
#
# After Crossover
# Coordinates: [4, 2, 0, 1, 3]
# Fitness 8
#
# Coordinates: [3, 2, 4, 1, 3]
# Fitness 8
#
# Coordinates: [2, 2, 4, 1, 3]
# Fitness 8
#
# Coordinates: [3, 2, 0, 1, 3]
# Fitness 7
#
# After Mutation
# Coordinates: [0, 2, 0, 1, 3]
# Fitness 8
#
# Coordinates: [3, 4, 4, 1, 3]
# Fitness 7
#
# Coordinates: [2, 2, 4, 1, 4]
# Fitness 7
#
# Coordinates: [3, 2, 1, 1, 3]
# Fitness 4
#
# Generation 71
#
# After Crossover
# Coordinates: [3, 4, 4, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 0, 1, 3]
# Fitness 8
#
# Coordinates: [2, 2, 0, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 4, 1, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [3, 4, 4, 1, 3]
# Fitness 7
#
# Coordinates: [0, 4, 0, 1, 3]
# Fitness 8
#
# Coordinates: [2, 2, 0, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Generation 72
#
# After Crossover
# Coordinates: [0, 4, 0, 1, 3]
# Fitness 8
#
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Coordinates: [3, 4, 4, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# After Mutation
# Coordinates: [0, 4, 0, 1, 2]
# Fitness 6
#
# Coordinates: [0, 2, 4, 1, 2]
# Fitness 7
#
# Coordinates: [3, 4, 2, 1, 3]
# Fitness 7
#
# Coordinates: [0, 4, 4, 1, 3]
# Fitness 9
#
# Generation 73
#
# After Crossover
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Coordinates: [0, 4, 4, 1, 2]
# Fitness 7
#
# Coordinates: [3, 4, 2, 1, 3]
# Fitness 7
#
# Coordinates: [0, 4, 4, 1, 3]
# Fitness 9
#
# After Mutation
# Coordinates: [0, 2, 3, 1, 3]
# Fitness 8
#
# Coordinates: [0, 4, 2, 1, 2]
# Fitness 6
#
# Coordinates: [3, 4, 2, 1, 3]
# Fitness 7
#
# Coordinates: [0, 4, 1, 1, 3]
# Fitness 8
#
# Generation 74
#
# After Crossover
# Coordinates: [0, 4, 1, 1, 3]
# Fitness 8
#
# Coordinates: [0, 2, 3, 1, 3]
# Fitness 8
#
# Coordinates: [3, 4, 2, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 3, 1, 3]
# Fitness 8
#
# After Mutation
# Coordinates: [0, 2, 1, 1, 3]
# Fitness 7
#
# Coordinates: [2, 2, 3, 1, 3]
# Fitness 7
#
# Coordinates: [3, 4, 2, 1, 3]
# Fitness 7
#
# Coordinates: [0, 1, 3, 1, 3]
# Fitness 7
#
# Generation 75
#
# After Crossover
# Coordinates: [2, 2, 3, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 1, 1, 3]
# Fitness 7
#
# Coordinates: [3, 4, 2, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 1, 1, 3]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 2, 1, 1, 3]
# Fitness 6
#
# Coordinates: [0, 3, 1, 1, 3]
# Fitness 6
#
# Coordinates: [3, 1, 2, 1, 3]
# Fitness 6
#
# Coordinates: [0, 2, 1, 1, 4]
# Fitness 7
#
# Generation 76
#
# After Crossover
# Coordinates: [2, 2, 1, 1, 4]
# Fitness 7
#
# Coordinates: [0, 2, 1, 1, 3]
# Fitness 7
#
# Coordinates: [0, 3, 1, 1, 4]
# Fitness 7
#
# Coordinates: [0, 2, 1, 1, 3]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 2, 1, 4, 4]
# Fitness 6
#
# Coordinates: [0, 2, 1, 1, 3]
# Fitness 7
#
# Coordinates: [0, 3, 1, 0, 4]
# Fitness 7
#
# Coordinates: [0, 2, 1, 1, 1]
# Fitness 6
#
# Generation 77
#
# After Crossover
# Coordinates: [0, 3, 1, 1, 3]
# Fitness 6
#
# Coordinates: [0, 2, 1, 0, 4]
# Fitness 5
#
# Coordinates: [2, 2, 1, 1, 3]
# Fitness 6
#
# Coordinates: [0, 2, 1, 4, 4]
# Fitness 6
#
# After Mutation
# Coordinates: [2, 3, 1, 1, 3]
# Fitness 5
#
# Coordinates: [2, 2, 1, 0, 4]
# Fitness 6
#
# Coordinates: [3, 2, 1, 1, 3]
# Fitness 4
#
# Coordinates: [0, 2, 3, 4, 4]
# Fitness 5
#
# Generation 78
#
# After Crossover
# Coordinates: [2, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [2, 2, 1, 1, 3]
# Fitness 6
#
# Coordinates: [0, 2, 3, 0, 4]
# Fitness 6
#
# Coordinates: [2, 2, 1, 4, 4]
# Fitness 6
#
# After Mutation
# Coordinates: [2, 2, 1, 0, 4]
# Fitness 6
#
# Coordinates: [2, 1, 1, 1, 3]
# Fitness 5
#
# Coordinates: [0, 2, 3, 0, 4]
# Fitness 6
#
# Coordinates: [2, 2, 4, 4, 4]
# Fitness 4
#
# Generation 79
#
# After Crossover
# Coordinates: [0, 2, 3, 0, 4]
# Fitness 6
#
# Coordinates: [2, 2, 1, 0, 4]
# Fitness 6
#
# Coordinates: [2, 1, 1, 0, 4]
# Fitness 6
#
# Coordinates: [2, 2, 1, 1, 3]
# Fitness 6
#
# After Mutation
# Coordinates: [0, 2, 4, 0, 4]
# Fitness 6
#
# Coordinates: [2, 2, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 1, 1, 0, 0]
# Fitness 6
#
# Coordinates: [2, 2, 1, 1, 0]
# Fitness 6
#
# Generation 80
#
# After Crossover
# Coordinates: [0, 2, 1, 3, 4]
# Fitness 6
#
# Coordinates: [2, 2, 4, 0, 4]
# Fitness 6
#
# Coordinates: [2, 1, 1, 3, 4]
# Fitness 5
#
# Coordinates: [2, 2, 1, 0, 0]
# Fitness 5
#
# After Mutation
# Coordinates: [0, 2, 2, 3, 4]
# Fitness 3
#
# Coordinates: [2, 2, 4, 0, 4]
# Fitness 6
#
# Coordinates: [2, 1, 1, 3, 4]
# Fitness 5
#
# Coordinates: [2, 2, 1, 0, 0]
# Fitness 5
#
# Generation 81
#
# After Crossover
# Coordinates: [2, 1, 1, 0, 4]
# Fitness 6
#
# Coordinates: [2, 2, 4, 3, 4]
# Fitness 5
#
# Coordinates: [2, 2, 1, 0, 4]
# Fitness 6
#
# Coordinates: [2, 2, 4, 0, 0]
# Fitness 6
#
# After Mutation
# Coordinates: [2, 1, 1, 0, 4]
# Fitness 6
#
# Coordinates: [2, 2, 4, 3, 4]
# Fitness 5
#
# Coordinates: [2, 2, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 2, 0, 0, 0]
# Fitness 4
#
# Generation 82
#
# After Crossover
# Coordinates: [2, 1, 1, 3, 4]
# Fitness 5
#
# Coordinates: [2, 2, 1, 0, 4]
# Fitness 6
#
# Coordinates: [2, 2, 4, 3, 4]
# Fitness 5
#
# Coordinates: [2, 2, 1, 3, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 1, 1, 3, 4]
# Fitness 5
#
# Coordinates: [2, 2, 1, 0, 4]
# Fitness 6
#
# Coordinates: [2, 2, 4, 3, 4]
# Fitness 5
#
# Coordinates: [2, 2, 1, 3, 4]
# Fitness 7
#
# Generation 83
#
# After Crossover
# Coordinates: [2, 2, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 2, 1, 0, 4]
# Fitness 6
#
# Coordinates: [2, 1, 1, 3, 4]
# Fitness 5
#
# Coordinates: [2, 2, 1, 3, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 3, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 2, 1, 0, 2]
# Fitness 4
#
# Coordinates: [2, 1, 0, 3, 4]
# Fitness 4
#
# Coordinates: [2, 2, 2, 3, 4]
# Fitness 4
#
# Generation 84
#
# After Crossover
# Coordinates: [2, 2, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 3, 1, 0, 2]
# Fitness 7
#
# Coordinates: [2, 1, 0, 3, 4]
# Fitness 4
#
# Coordinates: [2, 3, 1, 3, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 2, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 3, 1, 0, 2]
# Fitness 7
#
# Coordinates: [4, 1, 0, 3, 4]
# Fitness 5
#
# Coordinates: [2, 3, 1, 3, 4]
# Fitness 7
#
# Generation 85
#
# After Crossover
# Coordinates: [2, 3, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 2, 1, 0, 2]
# Fitness 4
#
# Coordinates: [2, 3, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 2, 1, 3, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 3, 1, 3, 4]
# Fitness 7
#
# Coordinates: [1, 2, 1, 0, 2]
# Fitness 4
#
# Coordinates: [1, 3, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 2, 1, 0, 4]
# Fitness 6
#
# Generation 86
#
# After Crossover
# Coordinates: [1, 3, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 3, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 2, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 3, 1, 0, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 1, 1, 3, 4]
# Fitness 4
#
# Coordinates: [4, 3, 1, 3, 4]
# Fitness 6
#
# Coordinates: [2, 2, 1, 3, 4]
# Fitness 7
#
# Coordinates: [2, 3, 1, 0, 4]
# Fitness 8
#
# Generation 87
#
# After Crossover
# Coordinates: [2, 2, 1, 0, 4]
# Fitness 6
#
# Coordinates: [2, 3, 1, 3, 4]
# Fitness 7
#
# Coordinates: [4, 3, 1, 0, 4]
# Fitness 7
#
# Coordinates: [2, 3, 1, 3, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [1, 2, 1, 0, 4]
# Fitness 5
#
# Coordinates: [2, 3, 3, 3, 4]
# Fitness 5
#
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [2, 3, 1, 2, 4]
# Fitness 7
#
# Generation 88
#
# After Crossover
# Coordinates: [2, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 1, 2, 4]
# Fitness 8
#
# Coordinates: [1, 2, 1, 0, 4]
# Fitness 5
#
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [2, 0, 1, 0, 4]
# Fitness 7
#
# Coordinates: [1, 1, 1, 2, 4]
# Fitness 5
#
# Coordinates: [2, 2, 1, 0, 4]
# Fitness 6
#
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Generation 89
#
# After Crossover
# Coordinates: [2, 0, 1, 0, 4]
# Fitness 7
#
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [2, 2, 1, 0, 4]
# Fitness 6
#
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [2, 0, 3, 0, 4]
# Fitness 9
#
# Coordinates: [1, 3, 1, 1, 4]
# Fitness 6
#
# Coordinates: [2, 2, 4, 0, 4]
# Fitness 6
#
# Coordinates: [1, 3, 1, 0, 0]
# Fitness 6
#
# Generation 90
#
# After Crossover
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [2, 0, 3, 1, 4]
# Fitness 10
#
# Coordinates: [2, 2, 3, 0, 4]
# Fitness 7
#
# Coordinates: [2, 0, 4, 0, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [0, 3, 1, 0, 4]
# Fitness 7
#
# Coordinates: [2, 0, 3, 1, 4]
# Fitness 10
#
# Coordinates: [2, 2, 3, 0, 3]
# Fitness 6
#
# Coordinates: [2, 0, 3, 0, 4]
# Fitness 9
#
# Generation 91
#
# After Crossover
# Coordinates: [2, 0, 3, 1, 4]
# Fitness 10
#
# Coordinates: [2, 0, 3, 0, 4]
# Fitness 9
#
# Coordinates: [0, 3, 1, 1, 4]
# Fitness 7
#
# Coordinates: [2, 0, 3, 0, 4]
# Fitness 9
#
# After Mutation
# Coordinates: [2, 1, 3, 1, 4]
# Fitness 7
#
# Coordinates: [2, 0, 3, 0, 4]
# Fitness 9
#
# Coordinates: [0, 3, 1, 1, 4]
# Fitness 7
#
# Coordinates: [2, 0, 3, 0, 4]
# Fitness 9
#
# Generation 92
#
# After Crossover
# Coordinates: [2, 0, 3, 0, 4]
# Fitness 9
#
# Coordinates: [2, 0, 3, 0, 4]
# Fitness 9
#
# Coordinates: [2, 1, 3, 0, 4]
# Fitness 8
#
# Coordinates: [2, 0, 3, 1, 4]
# Fitness 10
#
# After Mutation
# Coordinates: [2, 0, 4, 0, 4]
# Fitness 7
#
# Coordinates: [2, 0, 3, 0, 4]
# Fitness 9
#
# Coordinates: [2, 1, 0, 0, 4]
# Fitness 5
#
# Coordinates: [1, 0, 3, 1, 4]
# Fitness 7
#
# Generation 93
#
# After Crossover
# Coordinates: [2, 0, 4, 0, 4]
# Fitness 7
#
# Coordinates: [2, 0, 3, 0, 4]
# Fitness 9
#
# Coordinates: [1, 0, 3, 0, 4]
# Fitness 7
#
# Coordinates: [2, 0, 3, 1, 4]
# Fitness 10
#
# After Mutation
# Coordinates: [2, 0, 2, 0, 4]
# Fitness 7
#
# Coordinates: [2, 3, 3, 0, 4]
# Fitness 8
#
# Coordinates: [0, 0, 3, 0, 4]
# Fitness 6
#
# Coordinates: [1, 0, 3, 1, 4]
# Fitness 7
#
# Generation 94
#
# After Crossover
# Coordinates: [2, 0, 2, 0, 4]
# Fitness 7
#
# Coordinates: [2, 3, 3, 0, 4]
# Fitness 8
#
# Coordinates: [1, 0, 3, 0, 4]
# Fitness 7
#
# Coordinates: [2, 3, 3, 1, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 0, 2, 0, 4]
# Fitness 7
#
# Coordinates: [2, 3, 4, 0, 4]
# Fitness 6
#
# Coordinates: [1, 0, 4, 0, 4]
# Fitness 7
#
# Coordinates: [2, 3, 3, 1, 3]
# Fitness 5
#
# Generation 95
#
# After Crossover
# Coordinates: [1, 0, 2, 0, 4]
# Fitness 7
#
# Coordinates: [2, 0, 4, 0, 4]
# Fitness 7
#
# Coordinates: [2, 3, 2, 0, 4]
# Fitness 6
#
# Coordinates: [2, 0, 4, 0, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [1, 0, 4, 0, 4]
# Fitness 7
#
# Coordinates: [2, 0, 0, 0, 4]
# Fitness 6
#
# Coordinates: [2, 3, 2, 0, 4]
# Fitness 6
#
# Coordinates: [1, 0, 4, 0, 4]
# Fitness 7
#
# Generation 96
#
# After Crossover
# Coordinates: [1, 0, 4, 0, 4]
# Fitness 7
#
# Coordinates: [1, 0, 4, 0, 4]
# Fitness 7
#
# Coordinates: [2, 0, 4, 0, 4]
# Fitness 7
#
# Coordinates: [1, 0, 0, 0, 4]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 0, 0, 0, 4]
# Fitness 6
#
# Coordinates: [1, 3, 4, 0, 4]
# Fitness 8
#
# Coordinates: [2, 0, 4, 0, 4]
# Fitness 7
#
# Coordinates: [1, 0, 0, 0, 0]
# Fitness 3
#
# Generation 97
#
# After Crossover
# Coordinates: [2, 0, 4, 0, 4]
# Fitness 7
#
# Coordinates: [1, 3, 4, 0, 4]
# Fitness 8
#
# Coordinates: [1, 0, 4, 0, 4]
# Fitness 7
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# After Mutation
# Coordinates: [2, 0, 1, 0, 4]
# Fitness 7
#
# Coordinates: [1, 3, 4, 0, 0]
# Fitness 7
#
# Coordinates: [4, 0, 4, 0, 4]
# Fitness 6
#
# Coordinates: [1, 3, 0, 1, 4]
# Fitness 7
#
# Generation 98
#
# After Crossover
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [2, 0, 4, 0, 0]
# Fitness 6
#
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [2, 0, 0, 1, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [2, 0, 4, 0, 0]
# Fitness 6
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [2, 0, 0, 3, 4]
# Fitness 7
#
# Generation 99
#
# After Crossover
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [2, 0, 0, 0, 4]
# Fitness 6
#
# Coordinates: [1, 3, 0, 3, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 0, 2]
# Fitness 8
#
# Coordinates: [2, 0, 0, 0, 0]
# Fitness 3
#
# Coordinates: [1, 3, 1, 3, 4]
# Fitness 7
#
# Generation 100
#
# After Crossover
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 0, 2]
# Fitness 8
#
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 1, 3, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [1, 3, 2, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 0, 0]
# Fitness 6
#
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [0, 3, 1, 3, 4]
# Fitness 6
#
# Generation 101
#
# After Crossover
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 2, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [1, 3, 2, 0, 0]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 3, 1, 3, 4]
# Fitness 7
#
# Coordinates: [1, 3, 2, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [1, 3, 2, 2, 0]
# Fitness 6
#
# Generation 102
#
# After Crossover
# Coordinates: [1, 3, 2, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 3, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 3, 2, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [1, 3, 1, 1, 4]
# Fitness 6
#
# Coordinates: [1, 3, 0, 3, 4]
# Fitness 8
#
# Generation 103
#
# After Crossover
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [1, 3, 2, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [1, 3, 0, 3, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 3, 0, 4, 4]
# Fitness 8
#
# Coordinates: [0, 3, 2, 0, 4]
# Fitness 5
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [1, 3, 1, 3, 4]
# Fitness 7
#
# Generation 104
#
# After Crossover
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [1, 3, 0, 4, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [1, 3, 1, 3, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [1, 0, 0, 4, 4]
# Fitness 6
#
# Coordinates: [1, 3, 3, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 1, 3, 0]
# Fitness 7
#
# Generation 105
#
# After Crossover
# Coordinates: [1, 3, 3, 0, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 1, 0, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 3, 0]
# Fitness 9
#
# After Mutation
# Coordinates: [1, 3, 3, 1, 4]
# Fitness 6
#
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 1, 0, 3]
# Fitness 6
#
# Coordinates: [1, 4, 0, 4, 0]
# Fitness 7
#
# Generation 106
#
# After Crossover
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 4, 0]
# Fitness 7
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [1, 4, 3, 1, 4]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 0, 0]
# Fitness 7
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [1, 4, 3, 2, 4]
# Fitness 5
#
# Generation 107
#
# After Crossover
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 0, 4]
# Fitness 9
#
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 0, 0, 0]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [1, 3, 2, 0, 4]
# Fitness 8
#
# Coordinates: [1, 4, 4, 0, 4]
# Fitness 7
#
# Coordinates: [1, 3, 0, 0, 0]
# Fitness 6
#
# Generation 108
#
# After Crossover
# Coordinates: [1, 3, 2, 0, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [1, 4, 4, 0, 4]
# Fitness 7
#
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 2, 2, 0, 4]
# Fitness 6
#
# Coordinates: [1, 4, 0, 0, 0]
# Fitness 7
#
# Coordinates: [1, 4, 4, 0, 4]
# Fitness 7
#
# Coordinates: [1, 4, 2, 0, 4]
# Fitness 8
#
# Generation 109
#
# After Crossover
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [1, 4, 2, 0, 0]
# Fitness 8
#
# Coordinates: [1, 4, 2, 0, 4]
# Fitness 8
#
# Coordinates: [1, 4, 4, 0, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [3, 4, 2, 0, 0]
# Fitness 6
#
# Coordinates: [1, 4, 2, 4, 4]
# Fitness 5
#
# Coordinates: [1, 2, 4, 0, 4]
# Fitness 7
#
# Generation 110
#
# After Crossover
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [1, 2, 4, 0, 4]
# Fitness 7
#
# Coordinates: [3, 4, 4, 0, 4]
# Fitness 5
#
# Coordinates: [1, 2, 2, 0, 0]
# Fitness 5
#
# After Mutation
# Coordinates: [3, 4, 0, 3, 4]
# Fitness 6
#
# Coordinates: [4, 2, 4, 0, 4]
# Fitness 6
#
# Coordinates: [3, 3, 4, 0, 4]
# Fitness 6
#
# Coordinates: [1, 3, 2, 0, 0]
# Fitness 6
#
# Generation 111
#
# After Crossover
# Coordinates: [4, 2, 4, 3, 4]
# Fitness 5
#
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [3, 3, 4, 3, 4]
# Fitness 3
#
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# After Mutation
# Coordinates: [4, 0, 4, 3, 4]
# Fitness 5
#
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [3, 4, 4, 3, 4]
# Fitness 3
#
# Coordinates: [3, 4, 0, 0, 3]
# Fitness 6
#
# Generation 112
#
# After Crossover
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [3, 4, 0, 0, 3]
# Fitness 6
#
# Coordinates: [4, 0, 0, 0, 4]
# Fitness 6
#
# Coordinates: [3, 4, 4, 3, 4]
# Fitness 3
#
# After Mutation
# Coordinates: [3, 4, 0, 0, 2]
# Fitness 6
#
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [4, 0, 0, 0, 2]
# Fitness 6
#
# Coordinates: [3, 4, 3, 3, 4]
# Fitness 3
#
# Generation 113
#
# After Crossover
# Coordinates: [3, 4, 0, 0, 2]
# Fitness 6
#
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [4, 0, 0, 0, 2]
# Fitness 6
#
# Coordinates: [3, 4, 0, 0, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [3, 2, 0, 0, 4]
# Fitness 6
#
# Coordinates: [1, 0, 0, 0, 2]
# Fitness 5
#
# Coordinates: [3, 4, 0, 0, 2]
# Fitness 6
#
# Generation 114
#
# After Crossover
# Coordinates: [3, 2, 0, 0, 4]
# Fitness 6
#
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [3, 4, 0, 0, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [3, 2, 0, 0, 1]
# Fitness 5
#
# Coordinates: [3, 4, 0, 0, 2]
# Fitness 6
#
# Coordinates: [3, 0, 0, 0, 4]
# Fitness 6
#
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Generation 115
#
# After Crossover
# Coordinates: [3, 0, 0, 0, 2]
# Fitness 5
#
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [3, 4, 0, 0, 2]
# Fitness 6
#
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# After Mutation
# Coordinates: [3, 0, 0, 0, 0]
# Fitness 3
#
# Coordinates: [3, 4, 0, 4, 4]
# Fitness 6
#
# Coordinates: [4, 4, 0, 0, 2]
# Fitness 7
#
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Generation 116
#
# After Crossover
# Coordinates: [4, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [1, 4, 0, 0, 2]
# Fitness 8
#
# Coordinates: [3, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [1, 4, 0, 4, 4]
# Fitness 6
#
# After Mutation
# Coordinates: [4, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [3, 4, 3, 0, 4]
# Fitness 5
#
# Coordinates: [1, 4, 0, 1, 4]
# Fitness 7
#
# Generation 117
#
# After Crossover
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 1, 4]
# Fitness 7
#
# Coordinates: [4, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [2, 4, 0, 0, 4]
# Fitness 7
#
# Coordinates: [1, 4, 0, 1, 4]
# Fitness 7
#
# Coordinates: [4, 4, 0, 0, 2]
# Fitness 7
#
# Coordinates: [0, 4, 0, 0, 4]
# Fitness 5
#
# Generation 118
#
# After Crossover
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [2, 4, 0, 1, 4]
# Fitness 7
#
# Coordinates: [4, 4, 0, 0, 4]
# Fitness 6
#
# Coordinates: [2, 4, 0, 0, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 4, 0, 0, 1]
# Fitness 6
#
# Coordinates: [2, 3, 0, 1, 4]
# Fitness 6
#
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [2, 4, 0, 2, 2]
# Fitness 4
#
# Generation 119
#
# After Crossover
# Coordinates: [1, 4, 0, 0, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 0, 1]
# Fitness 6
#
# Coordinates: [2, 3, 0, 0, 4]
# Fitness 7
#
# Coordinates: [1, 4, 0, 1, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [1, 4, 0, 2, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 3, 1]
# Fitness 8
#
# Coordinates: [2, 3, 0, 0, 4]
# Fitness 7
#
# Coordinates: [1, 4, 0, 3, 4]
# Fitness 8
#
# Generation 120
#
# After Crossover
# Coordinates: [1, 4, 0, 2, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 4, 0, 2, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 3, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 4, 0, 2, 0]
# Fitness 8
#
# Coordinates: [1, 4, 0, 2, 1]
# Fitness 6
#
# Coordinates: [3, 4, 0, 2, 4]
# Fitness 7
#
# Coordinates: [1, 0, 0, 3, 4]
# Fitness 7
#
# Generation 121
#
# After Crossover
# Coordinates: [3, 4, 0, 2, 0]
# Fitness 7
#
# Coordinates: [1, 4, 0, 2, 4]
# Fitness 8
#
# Coordinates: [1, 0, 0, 2, 0]
# Fitness 5
#
# Coordinates: [1, 4, 0, 3, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [3, 4, 4, 2, 0]
# Fitness 7
#
# Coordinates: [1, 4, 0, 3, 4]
# Fitness 8
#
# Coordinates: [1, 0, 2, 2, 0]
# Fitness 5
#
# Coordinates: [1, 4, 0, 4, 4]
# Fitness 6
#
# Generation 122
#
# After Crossover
# Coordinates: [3, 4, 4, 3, 4]
# Fitness 3
#
# Coordinates: [1, 4, 0, 2, 0]
# Fitness 8
#
# Coordinates: [1, 4, 0, 3, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 4, 4]
# Fitness 6
#
# After Mutation
# Coordinates: [3, 4, 0, 3, 4]
# Fitness 6
#
# Coordinates: [1, 4, 0, 4, 0]
# Fitness 7
#
# Coordinates: [1, 4, 0, 2, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 3, 4]
# Fitness 8
#
# Generation 123
#
# After Crossover
# Coordinates: [1, 4, 0, 2, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 3, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 2, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 4, 0]
# Fitness 7
#
# After Mutation
# Coordinates: [1, 4, 1, 2, 4]
# Fitness 6
#
# Coordinates: [1, 4, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 2, 0, 2, 4]
# Fitness 8
#
# Coordinates: [1, 4, 0, 4, 1]
# Fitness 6
#
# Generation 124
#
# After Crossover
# Coordinates: [1, 2, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 4, 0, 2, 4]
# Fitness 8
#
# Coordinates: [1, 4, 1, 3, 1]
# Fitness 6
#
# Coordinates: [1, 4, 0, 2, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 2, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 4, 0, 2, 1]
# Fitness 6
#
# Coordinates: [1, 4, 1, 3, 1]
# Fitness 6
#
# Coordinates: [1, 4, 1, 2, 4]
# Fitness 6
#
# Generation 125
#
# After Crossover
# Coordinates: [1, 4, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 2, 0, 2, 1]
# Fitness 6
#
# Coordinates: [1, 4, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 2, 1, 3, 1]
# Fitness 5
#
# After Mutation
# Coordinates: [1, 4, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 2, 0, 0, 1]
# Fitness 5
#
# Coordinates: [1, 4, 0, 4, 1]
# Fitness 6
#
# Coordinates: [1, 2, 1, 3, 3]
# Fitness 5
#
# Generation 126
#
# After Crossover
# Coordinates: [1, 4, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 4, 0, 4, 1]
# Fitness 6
#
# Coordinates: [1, 2, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 4, 0, 0, 1]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 4, 0, 0, 1]
# Fitness 6
#
# Coordinates: [1, 4, 0, 4, 0]
# Fitness 7
#
# Coordinates: [1, 2, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 4, 2, 0, 1]
# Fitness 7
#
# Generation 127
#
# After Crossover
# Coordinates: [1, 4, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 2, 0, 4, 0]
# Fitness 6
#
# Coordinates: [1, 4, 2, 3, 1]
# Fitness 7
#
# Coordinates: [1, 2, 0, 0, 1]
# Fitness 5
#
# After Mutation
# Coordinates: [1, 4, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 4, 0, 4, 0]
# Fitness 7
#
# Coordinates: [1, 4, 2, 3, 1]
# Fitness 7
#
# Coordinates: [3, 2, 0, 0, 1]
# Fitness 5
#
# Generation 128
#
# After Crossover
# Coordinates: [1, 4, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 4, 0, 4, 0]
# Fitness 7
#
# Coordinates: [1, 4, 2, 3, 1]
# Fitness 7
#
# Coordinates: [1, 4, 0, 3, 1]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 0, 0, 3, 1]
# Fitness 7
#
# Coordinates: [1, 4, 0, 4, 0]
# Fitness 7
#
# Coordinates: [1, 3, 2, 3, 1]
# Fitness 6
#
# Coordinates: [1, 4, 0, 3, 3]
# Fitness 9
#
# Generation 129
#
# After Crossover
# Coordinates: [1, 0, 0, 3, 3]
# Fitness 6
#
# Coordinates: [1, 4, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 4, 0, 3, 3]
# Fitness 9
#
# Coordinates: [1, 4, 0, 4, 0]
# Fitness 7
#
# After Mutation
# Coordinates: [1, 0, 3, 3, 3]
# Fitness 4
#
# Coordinates: [1, 4, 0, 4, 1]
# Fitness 6
#
# Coordinates: [1, 4, 0, 3, 2]
# Fitness 8
#
# Coordinates: [1, 4, 0, 4, 0]
# Fitness 7
#
# Generation 130
#
# After Crossover
# Coordinates: [1, 4, 0, 3, 2]
# Fitness 8
#
# Coordinates: [1, 4, 0, 4, 0]
# Fitness 7
#
# Coordinates: [1, 4, 0, 3, 2]
# Fitness 8
#
# Coordinates: [1, 4, 0, 4, 1]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 4, 0, 4, 2]
# Fitness 7
#
# Coordinates: [1, 2, 0, 4, 0]
# Fitness 6
#
# Coordinates: [1, 4, 0, 3, 3]
# Fitness 9
#
# Coordinates: [1, 4, 2, 4, 1]
# Fitness 6
#
# Generation 131
#
# After Crossover
# Coordinates: [1, 4, 0, 3, 3]
# Fitness 9
#
# Coordinates: [1, 4, 0, 4, 2]
# Fitness 7
#
# Coordinates: [1, 2, 0, 3, 3]
# Fitness 8
#
# Coordinates: [1, 4, 0, 4, 0]
# Fitness 7
#
# After Mutation
# Coordinates: [1, 2, 0, 3, 3]
# Fitness 8
#
# Coordinates: [1, 4, 0, 4, 4]
# Fitness 6
#
# Coordinates: [1, 2, 0, 1, 3]
# Fitness 7
#
# Coordinates: [1, 4, 2, 4, 0]
# Fitness 7
#
# Generation 132
#
# After Crossover
# Coordinates: [1, 2, 0, 3, 3]
# Fitness 8
#
# Coordinates: [1, 2, 0, 1, 3]
# Fitness 7
#
# Coordinates: [1, 4, 2, 3, 3]
# Fitness 8
#
# Coordinates: [1, 2, 0, 4, 0]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 2, 0, 3, 3]
# Fitness 8
#
# Coordinates: [1, 2, 0, 4, 3]
# Fitness 6
#
# Coordinates: [1, 1, 2, 3, 3]
# Fitness 5
#
# Coordinates: [1, 2, 2, 4, 0]
# Fitness 5
#
# Generation 133
#
# After Crossover
# Coordinates: [1, 2, 0, 3, 3]
# Fitness 8
#
# Coordinates: [1, 2, 0, 4, 3]
# Fitness 6
#
# Coordinates: [1, 1, 0, 3, 3]
# Fitness 6
#
# Coordinates: [1, 2, 2, 3, 3]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 2, 0, 3, 3]
# Fitness 8
#
# Coordinates: [1, 2, 0, 4, 2]
# Fitness 5
#
# Coordinates: [1, 1, 0, 3, 2]
# Fitness 5
#
# Coordinates: [1, 2, 2, 3, 2]
# Fitness 4
#
# Generation 134
#
# After Crossover
# Coordinates: [1, 2, 0, 3, 3]
# Fitness 8
#
# Coordinates: [1, 2, 0, 4, 2]
# Fitness 5
#
# Coordinates: [1, 1, 0, 3, 3]
# Fitness 6
#
# Coordinates: [1, 2, 0, 3, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 2, 0, 3, 2]
# Fitness 6
#
# Coordinates: [1, 2, 0, 4, 0]
# Fitness 6
#
# Coordinates: [1, 1, 0, 3, 1]
# Fitness 5
#
# Coordinates: [1, 2, 0, 3, 2]
# Fitness 6
#
# Generation 135
#
# After Crossover
# Coordinates: [1, 2, 0, 3, 2]
# Fitness 6
#
# Coordinates: [1, 2, 0, 4, 0]
# Fitness 6
#
# Coordinates: [1, 2, 0, 3, 2]
# Fitness 6
#
# Coordinates: [1, 2, 0, 3, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 2, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 2, 0, 4, 0]
# Fitness 6
#
# Coordinates: [1, 2, 4, 3, 2]
# Fitness 5
#
# Coordinates: [4, 2, 0, 3, 2]
# Fitness 7
#
# Generation 136
#
# After Crossover
# Coordinates: [4, 2, 0, 3, 1]
# Fitness 10
#
# Coordinates: [1, 2, 0, 3, 2]
# Fitness 6
#
# Coordinates: [1, 2, 0, 3, 1]
# Fitness 8
#
# Coordinates: [1, 2, 0, 4, 0]
# Fitness 6
#
# After Mutation
# Coordinates: [4, 2, 0, 2, 1]
# Fitness 8
#
# Coordinates: [1, 2, 4, 3, 2]
# Fitness 5
#
# Coordinates: [1, 2, 0, 2, 1]
# Fitness 6
#
# Coordinates: [1, 2, 0, 4, 0]
# Fitness 6
#
# Generation 137
#
# After Crossover
# Coordinates: [1, 2, 0, 2, 1]
# Fitness 6
#
# Coordinates: [4, 2, 0, 2, 1]
# Fitness 8
#
# Coordinates: [1, 2, 0, 2, 1]
# Fitness 6
#
# Coordinates: [4, 2, 0, 4, 0]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 3, 0, 2, 1]
# Fitness 8
#
# Coordinates: [4, 2, 0, 2, 1]
# Fitness 8
#
# Coordinates: [3, 2, 0, 2, 1]
# Fitness 7
#
# Coordinates: [0, 2, 0, 4, 0]
# Fitness 6
#
# Generation 138
#
# After Crossover
# Coordinates: [4, 2, 0, 2, 1]
# Fitness 8
#
# Coordinates: [1, 3, 0, 2, 1]
# Fitness 8
#
# Coordinates: [3, 2, 0, 2, 1]
# Fitness 7
#
# Coordinates: [1, 3, 0, 2, 1]
# Fitness 8
#
# After Mutation
# Coordinates: [4, 2, 0, 2, 1]
# Fitness 8
#
# Coordinates: [1, 3, 0, 1, 1]
# Fitness 5
#
# Coordinates: [3, 2, 2, 2, 1]
# Fitness 5
#
# Coordinates: [0, 3, 0, 2, 1]
# Fitness 8
#
# Generation 139
#
# After Crossover
# Coordinates: [0, 3, 0, 2, 1]
# Fitness 8
#
# Coordinates: [4, 2, 0, 2, 1]
# Fitness 8
#
# Coordinates: [1, 3, 0, 2, 1]
# Fitness 8
#
# Coordinates: [4, 2, 0, 1, 1]
# Fitness 7
#
# After Mutation
# Coordinates: [0, 3, 0, 3, 1]
# Fitness 7
#
# Coordinates: [4, 2, 0, 0, 1]
# Fitness 7
#
# Coordinates: [3, 3, 0, 2, 1]
# Fitness 8
#
# Coordinates: [4, 2, 0, 1, 4]
# Fitness 7
#
# Generation 140
#
# After Crossover
# Coordinates: [0, 3, 0, 2, 1]
# Fitness 8
#
# Coordinates: [3, 3, 0, 3, 1]
# Fitness 7
#
# Coordinates: [4, 2, 0, 2, 1]
# Fitness 8
#
# Coordinates: [3, 3, 0, 0, 1]
# Fitness 6
#
# After Mutation
# Coordinates: [0, 0, 0, 2, 1]
# Fitness 5
#
# Coordinates: [3, 3, 3, 3, 1]
# Fitness 3
#
# Coordinates: [4, 2, 0, 2, 2]
# Fitness 6
#
# Coordinates: [3, 3, 0, 0, 3]
# Fitness 5
#
# Generation 141
#
# After Crossover
# Coordinates: [0, 0, 0, 2, 2]
# Fitness 4
#
# Coordinates: [4, 2, 0, 2, 1]
# Fitness 8
#
# Coordinates: [3, 3, 0, 2, 2]
# Fitness 7
#
# Coordinates: [4, 2, 0, 0, 3]
# Fitness 8
#
# After Mutation
# Coordinates: [3, 0, 0, 2, 2]
# Fitness 6
#
# Coordinates: [2, 2, 0, 2, 1]
# Fitness 5
#
# Coordinates: [3, 0, 0, 2, 2]
# Fitness 6
#
# Coordinates: [4, 4, 0, 0, 3]
# Fitness 8
#
# Generation 142
#
# After Crossover
# Coordinates: [3, 0, 0, 0, 3]
# Fitness 4
#
# Coordinates: [4, 4, 0, 2, 2]
# Fitness 6
#
# Coordinates: [3, 0, 0, 0, 3]
# Fitness 4
#
# Coordinates: [4, 4, 0, 2, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [3, 0, 0, 3, 3]
# Fitness 5
#
# Coordinates: [4, 4, 0, 2, 4]
# Fitness 6
#
# Coordinates: [3, 0, 2, 0, 3]
# Fitness 6
#
# Coordinates: [4, 4, 0, 2, 1]
# Fitness 6
#
# Generation 143
#
# After Crossover
# Coordinates: [3, 0, 2, 2, 4]
# Fitness 7
#
# Coordinates: [4, 4, 0, 0, 3]
# Fitness 8
#
# Coordinates: [4, 4, 0, 2, 4]
# Fitness 6
#
# Coordinates: [4, 4, 0, 2, 1]
# Fitness 6
#
# After Mutation
# Coordinates: [3, 0, 2, 4, 4]
# Fitness 8
#
# Coordinates: [4, 4, 2, 0, 3]
# Fitness 8
#
# Coordinates: [4, 3, 0, 2, 4]
# Fitness 8
#
# Coordinates: [4, 4, 4, 2, 1]
# Fitness 4
#
# Generation 144
#
# After Crossover
# Coordinates: [4, 4, 2, 4, 4]
# Fitness 2
#
# Coordinates: [3, 0, 2, 0, 3]
# Fitness 6
#
# Coordinates: [4, 3, 0, 4, 4]
# Fitness 6
#
# Coordinates: [3, 0, 2, 2, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [4, 1, 2, 4, 4]
# Fitness 3
#
# Coordinates: [3, 0, 2, 0, 4]
# Fitness 7
#
# Coordinates: [4, 3, 2, 4, 4]
# Fitness 3
#
# Coordinates: [3, 0, 2, 2, 2]
# Fitness 6
#
# Generation 145
#
# After Crossover
# Coordinates: [3, 0, 2, 0, 4]
# Fitness 7
#
# Coordinates: [3, 0, 2, 2, 2]
# Fitness 6
#
# Coordinates: [4, 1, 2, 0, 4]
# Fitness 5
#
# Coordinates: [3, 0, 2, 4, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [3, 0, 1, 0, 4]
# Fitness 5
#
# Coordinates: [3, 1, 2, 2, 2]
# Fitness 6
#
# Coordinates: [4, 1, 2, 0, 1]
# Fitness 6
#
# Coordinates: [3, 0, 2, 0, 4]
# Fitness 7
#
# Generation 146
#
# After Crossover
# Coordinates: [3, 1, 2, 0, 4]
# Fitness 6
#
# Coordinates: [3, 0, 2, 2, 2]
# Fitness 6
#
# Coordinates: [4, 1, 2, 0, 4]
# Fitness 5
#
# Coordinates: [3, 0, 2, 0, 1]
# Fitness 7
#
# After Mutation
# Coordinates: [3, 1, 2, 0, 4]
# Fitness 6
#
# Coordinates: [3, 0, 2, 2, 2]
# Fitness 6
#
# Coordinates: [4, 1, 2, 0, 2]
# Fitness 7
#
# Coordinates: [3, 1, 2, 0, 1]
# Fitness 6
#
# Generation 147
#
# After Crossover
# Coordinates: [3, 1, 2, 0, 2]
# Fitness 7
#
# Coordinates: [4, 1, 2, 0, 4]
# Fitness 5
#
# Coordinates: [3, 0, 2, 0, 2]
# Fitness 7
#
# Coordinates: [4, 1, 2, 2, 2]
# Fitness 5
#
# After Mutation
# Coordinates: [3, 0, 2, 0, 2]
# Fitness 7
#
# Coordinates: [4, 1, 4, 0, 4]
# Fitness 6
#
# Coordinates: [3, 0, 2, 4, 2]
# Fitness 9
#
# Coordinates: [2, 1, 2, 2, 2]
# Fitness 2
#
# Generation 148
#
# After Crossover
# Coordinates: [3, 0, 2, 4, 2]
# Fitness 9
#
# Coordinates: [3, 0, 2, 0, 2]
# Fitness 7
#
# Coordinates: [4, 1, 2, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 4, 0, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [4, 0, 2, 4, 2]
# Fitness 7
#
# Coordinates: [3, 2, 2, 0, 2]
# Fitness 4
#
# Coordinates: [4, 1, 2, 4, 1]
# Fitness 6
#
# Coordinates: [3, 1, 4, 0, 4]
# Fitness 7
#
# Generation 149
#
# After Crossover
# Coordinates: [3, 1, 2, 4, 2]
# Fitness 8
#
# Coordinates: [4, 0, 4, 0, 4]
# Fitness 6
#
# Coordinates: [4, 1, 2, 4, 2]
# Fitness 6
#
# Coordinates: [4, 0, 2, 4, 1]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 1, 2, 4, 2]
# Fitness 6
#
# Coordinates: [4, 0, 4, 0, 0]
# Fitness 5
#
# Coordinates: [4, 1, 0, 4, 2]
# Fitness 7
#
# Coordinates: [4, 0, 3, 4, 1]
# Fitness 7
#
# Generation 150
#
# After Crossover
# Coordinates: [4, 0, 0, 4, 2]
# Fitness 7
#
# Coordinates: [4, 1, 3, 4, 1]
# Fitness 6
#
# Coordinates: [1, 1, 0, 4, 2]
# Fitness 6
#
# Coordinates: [4, 1, 2, 4, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [4, 0, 0, 4, 4]
# Fitness 6
#
# Coordinates: [3, 1, 3, 4, 1]
# Fitness 6
#
# Coordinates: [1, 1, 0, 4, 2]
# Fitness 6
#
# Coordinates: [4, 1, 0, 4, 2]
# Fitness 7
#
# Generation 151
#
# After Crossover
# Coordinates: [4, 0, 0, 4, 2]
# Fitness 7
#
# Coordinates: [4, 1, 0, 4, 4]
# Fitness 5
#
# Coordinates: [3, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [4, 1, 0, 4, 1]
# Fitness 7
#
# After Mutation
# Coordinates: [4, 0, 0, 4, 0]
# Fitness 5
#
# Coordinates: [4, 1, 4, 4, 4]
# Fitness 3
#
# Coordinates: [2, 1, 3, 4, 2]
# Fitness 7
#
# Coordinates: [4, 1, 0, 4, 0]
# Fitness 6
#
# Generation 152
#
# After Crossover
# Coordinates: [4, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [2, 1, 0, 4, 0]
# Fitness 6
#
# Coordinates: [4, 0, 0, 4, 2]
# Fitness 7
#
# Coordinates: [2, 1, 3, 4, 0]
# Fitness 8
#
# After Mutation
# Coordinates: [4, 2, 3, 4, 2]
# Fitness 5
#
# Coordinates: [0, 1, 0, 4, 0]
# Fitness 5
#
# Coordinates: [4, 0, 0, 1, 2]
# Fitness 5
#
# Coordinates: [2, 1, 3, 4, 0]
# Fitness 8
#
# Generation 153
#
# After Crossover
# Coordinates: [4, 2, 3, 4, 0]
# Fitness 5
#
# Coordinates: [2, 1, 3, 4, 2]
# Fitness 7
#
# Coordinates: [0, 1, 0, 4, 0]
# Fitness 5
#
# Coordinates: [2, 1, 3, 4, 0]
# Fitness 8
#
# After Mutation
# Coordinates: [4, 2, 3, 0, 0]
# Fitness 6
#
# Coordinates: [2, 1, 3, 4, 2]
# Fitness 7
#
# Coordinates: [4, 1, 0, 4, 0]
# Fitness 6
#
# Coordinates: [2, 1, 3, 3, 0]
# Fitness 7
#
# Generation 154
#
# After Crossover
# Coordinates: [2, 1, 3, 4, 2]
# Fitness 7
#
# Coordinates: [2, 1, 3, 3, 0]
# Fitness 7
#
# Coordinates: [4, 2, 3, 4, 2]
# Fitness 5
#
# Coordinates: [2, 1, 3, 0, 0]
# Fitness 8
#
# After Mutation
# Coordinates: [2, 1, 3, 3, 2]
# Fitness 5
#
# Coordinates: [2, 1, 3, 2, 0]
# Fitness 7
#
# Coordinates: [4, 2, 3, 4, 4]
# Fitness 4
#
# Coordinates: [4, 1, 3, 0, 0]
# Fitness 8
#
# Generation 155
#
# After Crossover
# Coordinates: [2, 1, 3, 0, 0]
# Fitness 8
#
# Coordinates: [4, 1, 3, 2, 0]
# Fitness 8
#
# Coordinates: [2, 1, 3, 0, 0]
# Fitness 8
#
# Coordinates: [4, 1, 3, 3, 2]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 4, 3, 0, 0]
# Fitness 8
#
# Coordinates: [4, 1, 3, 2, 0]
# Fitness 8
#
# Coordinates: [2, 1, 1, 0, 0]
# Fitness 6
#
# Coordinates: [4, 1, 3, 1, 2]
# Fitness 7
#
# Generation 156
#
# After Crossover
# Coordinates: [4, 1, 3, 0, 0]
# Fitness 8
#
# Coordinates: [2, 4, 3, 2, 0]
# Fitness 6
#
# Coordinates: [4, 1, 3, 0, 0]
# Fitness 8
#
# Coordinates: [2, 4, 3, 1, 2]
# Fitness 7
#
# After Mutation
# Coordinates: [4, 1, 3, 0, 1]
# Fitness 7
#
# Coordinates: [2, 4, 3, 2, 0]
# Fitness 6
#
# Coordinates: [2, 1, 3, 0, 0]
# Fitness 8
#
# Coordinates: [2, 4, 0, 1, 2]
# Fitness 5
#
# Generation 157
#
# After Crossover
# Coordinates: [4, 1, 3, 0, 0]
# Fitness 8
#
# Coordinates: [2, 1, 3, 0, 1]
# Fitness 6
#
# Coordinates: [2, 4, 3, 0, 0]
# Fitness 8
#
# Coordinates: [2, 1, 3, 2, 0]
# Fitness 7
#
# After Mutation
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# Coordinates: [2, 1, 3, 1, 1]
# Fitness 5
#
# Coordinates: [2, 4, 2, 0, 0]
# Fitness 7
#
# Coordinates: [2, 2, 3, 2, 0]
# Fitness 5
#
# Generation 158
#
# After Crossover
# Coordinates: [2, 4, 2, 4, 0]
# Fitness 7
#
# Coordinates: [4, 1, 3, 0, 0]
# Fitness 8
#
# Coordinates: [2, 1, 3, 4, 0]
# Fitness 8
#
# Coordinates: [4, 1, 3, 1, 1]
# Fitness 5
#
# After Mutation
# Coordinates: [2, 2, 2, 4, 0]
# Fitness 5
#
# Coordinates: [4, 1, 3, 0, 1]
# Fitness 7
#
# Coordinates: [2, 1, 2, 4, 0]
# Fitness 6
#
# Coordinates: [4, 1, 3, 1, 3]
# Fitness 7
#
# Generation 159
#
# After Crossover
# Coordinates: [4, 1, 3, 0, 1]
# Fitness 7
#
# Coordinates: [4, 1, 3, 1, 3]
# Fitness 7
#
# Coordinates: [2, 1, 2, 0, 1]
# Fitness 5
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# After Mutation
# Coordinates: [4, 3, 3, 0, 1]
# Fitness 6
#
# Coordinates: [4, 1, 3, 1, 3]
# Fitness 7
#
# Coordinates: [2, 1, 1, 0, 1]
# Fitness 4
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# Generation 160
#
# After Crossover
# Coordinates: [4, 1, 3, 1, 3]
# Fitness 7
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# Coordinates: [4, 3, 3, 1, 3]
# Fitness 4
#
# Coordinates: [4, 1, 3, 0, 1]
# Fitness 7
#
# After Mutation
# Coordinates: [4, 3, 3, 1, 3]
# Fitness 4
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# Coordinates: [4, 3, 3, 4, 3]
# Fitness 3
#
# Coordinates: [4, 1, 3, 0, 2]
# Fitness 10
#
# Generation 161
#
# After Crossover
# Coordinates: [4, 1, 3, 0, 2]
# Fitness 10
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# Coordinates: [4, 3, 3, 0, 2]
# Fitness 8
#
# Coordinates: [4, 1, 3, 1, 3]
# Fitness 7
#
# After Mutation
# Coordinates: [4, 1, 2, 0, 2]
# Fitness 7
#
# Coordinates: [1, 1, 3, 4, 0]
# Fitness 6
#
# Coordinates: [4, 3, 3, 0, 3]
# Fitness 6
#
# Coordinates: [4, 1, 3, 1, 1]
# Fitness 5
#
# Generation 162
#
# After Crossover
# Coordinates: [1, 1, 2, 0, 2]
# Fitness 7
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# Coordinates: [4, 3, 2, 0, 2]
# Fitness 6
#
# Coordinates: [4, 1, 3, 0, 3]
# Fitness 9
#
# After Mutation
# Coordinates: [1, 1, 2, 2, 2]
# Fitness 5
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# Coordinates: [4, 0, 2, 0, 2]
# Fitness 7
#
# Coordinates: [4, 1, 3, 0, 3]
# Fitness 9
#
# Generation 163
#
# After Crossover
# Coordinates: [4, 1, 3, 0, 3]
# Fitness 9
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# Coordinates: [4, 0, 2, 0, 3]
# Fitness 7
#
# Coordinates: [4, 1, 3, 0, 2]
# Fitness 10
#
# After Mutation
# Coordinates: [4, 1, 3, 0, 3]
# Fitness 9
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# Coordinates: [4, 0, 2, 0, 3]
# Fitness 7
#
# Coordinates: [0, 1, 3, 0, 2]
# Fitness 8
#
# Generation 164
#
# After Crossover
# Coordinates: [0, 1, 3, 0, 3]
# Fitness 7
#
# Coordinates: [4, 1, 3, 0, 2]
# Fitness 10
#
# Coordinates: [4, 1, 3, 0, 3]
# Fitness 9
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# After Mutation
# Coordinates: [0, 1, 1, 0, 3]
# Fitness 5
#
# Coordinates: [4, 1, 3, 0, 0]
# Fitness 8
#
# Coordinates: [4, 3, 3, 0, 3]
# Fitness 6
#
# Coordinates: [3, 1, 3, 4, 0]
# Fitness 8
#
# Generation 165
#
# After Crossover
# Coordinates: [3, 1, 3, 0, 0]
# Fitness 7
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# Coordinates: [4, 3, 3, 0, 0]
# Fitness 5
#
# Coordinates: [4, 1, 3, 0, 3]
# Fitness 9
#
# After Mutation
# Coordinates: [3, 1, 3, 0, 2]
# Fitness 8
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# Coordinates: [4, 3, 3, 0, 3]
# Fitness 6
#
# Coordinates: [4, 1, 0, 0, 3]
# Fitness 8
#
# Generation 166
#
# After Crossover
# Coordinates: [4, 1, 3, 0, 2]
# Fitness 10
#
# Coordinates: [3, 1, 0, 0, 3]
# Fitness 6
#
# Coordinates: [4, 1, 3, 0, 2]
# Fitness 10
#
# Coordinates: [3, 1, 3, 4, 0]
# Fitness 8
#
# After Mutation
# Coordinates: [4, 2, 3, 0, 2]
# Fitness 7
#
# Coordinates: [3, 1, 0, 0, 3]
# Fitness 6
#
# Coordinates: [4, 1, 3, 0, 2]
# Fitness 10
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# Generation 167
#
# After Crossover
# Coordinates: [4, 2, 3, 0, 2]
# Fitness 7
#
# Coordinates: [4, 1, 3, 0, 2]
# Fitness 10
#
# Coordinates: [4, 1, 3, 0, 2]
# Fitness 10
#
# Coordinates: [4, 1, 3, 4, 0]
# Fitness 7
#
# After Mutation
# Coordinates: [4, 2, 3, 1, 2]
# Fitness 6
#
# Coordinates: [3, 1, 3, 0, 2]
# Fitness 8
#
# Coordinates: [4, 1, 4, 0, 2]
# Fitness 8
#
# Coordinates: [3, 1, 3, 4, 0]
# Fitness 8
#
# Generation 168
#
# After Crossover
# Coordinates: [4, 1, 3, 0, 2]
# Fitness 10
#
# Coordinates: [3, 1, 4, 0, 2]
# Fitness 8
#
# Coordinates: [3, 1, 3, 0, 2]
# Fitness 8
#
# Coordinates: [3, 1, 3, 4, 0]
# Fitness 8
#
# After Mutation
# Coordinates: [4, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [3, 1, 4, 0, 2]
# Fitness 8
#
# Coordinates: [3, 1, 3, 3, 2]
# Fitness 5
#
# Coordinates: [3, 1, 3, 4, 4]
# Fitness 6
#
# Generation 169
#
# After Crossover
# Coordinates: [3, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [4, 1, 4, 0, 2]
# Fitness 8
#
# Coordinates: [3, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [4, 1, 3, 4, 4]
# Fitness 5
#
# After Mutation
# Coordinates: [3, 3, 3, 4, 2]
# Fitness 6
#
# Coordinates: [4, 1, 4, 4, 2]
# Fitness 6
#
# Coordinates: [3, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [4, 1, 3, 4, 1]
# Fitness 6
#
# Generation 170
#
# After Crossover
# Coordinates: [3, 3, 3, 4, 2]
# Fitness 6
#
# Coordinates: [3, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [4, 1, 4, 4, 2]
# Fitness 6
#
# Coordinates: [3, 1, 3, 4, 2]
# Fitness 8
#
# After Mutation
# Coordinates: [3, 3, 3, 4, 2]
# Fitness 6
#
# Coordinates: [1, 1, 3, 4, 2]
# Fitness 6
#
# Coordinates: [4, 1, 4, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 3, 4, 2]
# Fitness 8
#
# Generation 171
#
# After Crossover
# Coordinates: [3, 3, 3, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 3, 4, 2]
# Fitness 8
#
# Coordinates: [1, 1, 3, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 3, 4, 2]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 3, 3, 4, 2]
# Fitness 6
#
# Coordinates: [3, 4, 3, 4, 2]
# Fitness 5
#
# Coordinates: [1, 1, 3, 2, 2]
# Fitness 6
#
# Coordinates: [3, 0, 3, 4, 2]
# Fitness 8
#
# Generation 172
#
# After Crossover
# Coordinates: [1, 3, 3, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 3, 4, 2]
# Fitness 8
#
# Coordinates: [1, 1, 3, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 3, 2, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [1, 3, 3, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 3, 4, 2]
# Fitness 8
#
# Coordinates: [1, 1, 4, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 3, 2, 2]
# Fitness 6
#
# Generation 173
#
# After Crossover
# Coordinates: [1, 3, 3, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 3, 4, 2]
# Fitness 8
#
# Coordinates: [1, 1, 3, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 4, 4, 2]
# Fitness 8
#
# After Mutation
# Coordinates: [0, 3, 3, 4, 2]
# Fitness 8
#
# Coordinates: [3, 0, 0, 4, 2]
# Fitness 8
#
# Coordinates: [0, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [4, 0, 4, 4, 2]
# Fitness 6
#
# Generation 174
#
# After Crossover
# Coordinates: [3, 0, 3, 4, 2]
# Fitness 8
#
# Coordinates: [0, 3, 0, 4, 2]
# Fitness 8
#
# Coordinates: [0, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [0, 3, 3, 4, 2]
# Fitness 8
#
# After Mutation
# Coordinates: [3, 0, 3, 4, 2]
# Fitness 8
#
# Coordinates: [4, 3, 0, 4, 2]
# Fitness 7
#
# Coordinates: [0, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [0, 3, 3, 0, 2]
# Fitness 8
#
# Generation 175
#
# After Crossover
# Coordinates: [0, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [3, 0, 3, 4, 2]
# Fitness 8
#
# Coordinates: [0, 3, 3, 4, 2]
# Fitness 8
#
# Coordinates: [3, 0, 3, 0, 2]
# Fitness 7
#
# After Mutation
# Coordinates: [0, 1, 1, 4, 2]
# Fitness 8
#
# Coordinates: [3, 0, 3, 4, 4]
# Fitness 7
#
# Coordinates: [0, 3, 3, 4, 2]
# Fitness 8
#
# Coordinates: [3, 0, 3, 0, 2]
# Fitness 7
#
# Generation 176
#
# After Crossover
# Coordinates: [0, 3, 3, 4, 2]
# Fitness 8
#
# Coordinates: [0, 1, 1, 4, 2]
# Fitness 8
#
# Coordinates: [3, 0, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 1, 3, 4, 4]
# Fitness 5
#
# After Mutation
# Coordinates: [0, 3, 3, 1, 2]
# Fitness 7
#
# Coordinates: [1, 1, 1, 4, 2]
# Fitness 6
#
# Coordinates: [3, 0, 1, 0, 2]
# Fitness 5
#
# Coordinates: [0, 1, 3, 4, 3]
# Fitness 6
#
# Generation 177
#
# After Crossover
# Coordinates: [1, 1, 3, 1, 2]
# Fitness 5
#
# Coordinates: [0, 3, 1, 4, 2]
# Fitness 10
#
# Coordinates: [0, 1, 3, 1, 2]
# Fitness 7
#
# Coordinates: [0, 3, 3, 4, 3]
# Fitness 5
#
# After Mutation
# Coordinates: [3, 1, 3, 1, 2]
# Fitness 7
#
# Coordinates: [4, 3, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 1, 3, 1, 2]
# Fitness 7
#
# Coordinates: [4, 3, 3, 4, 3]
# Fitness 3
#
# Generation 178
#
# After Crossover
# Coordinates: [3, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [4, 3, 1, 1, 2]
# Fitness 5
#
# Coordinates: [0, 1, 1, 4, 2]
# Fitness 8
#
# Coordinates: [4, 3, 3, 1, 2]
# Fitness 5
#
# After Mutation
# Coordinates: [4, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [4, 3, 1, 2, 2]
# Fitness 7
#
# Coordinates: [0, 1, 1, 2, 2]
# Fitness 6
#
# Coordinates: [4, 3, 3, 1, 2]
# Fitness 5
#
# Generation 179
#
# After Crossover
# Coordinates: [4, 3, 3, 4, 2]
# Fitness 6
#
# Coordinates: [4, 1, 1, 2, 2]
# Fitness 7
#
# Coordinates: [0, 1, 3, 4, 2]
# Fitness 8
#
# Coordinates: [4, 1, 1, 2, 2]
# ...
# Fitness 5
#
# Coordinates: [0, 4, 1, 4, 2]
# Fitness 9
#
# Coordinates: [2, 3, 3, 3, 2]
# Fitness 4
#
# Coordinates: [0, 4, 1, 4, 2]
# Fitness 9
#
# After Mutation
# Coordinates: [1, 1, 1, 4, 2]
# Fitness 6
#
# Coordinates: [0, 4, 1, 4, 2]
# Fitness 9
#
# Coordinates: [2, 3, 0, 3, 2]
# Fitness 4
#
# Coordinates: [0, 4, 1, 4, 2]
# Fitness 9
#
# Generation 185
#
# After Crossover
# Coordinates: [0, 4, 1, 4, 2]
# Fitness 9
#
# Coordinates: [0, 4, 1, 4, 2]
# Fitness 9
#
# Coordinates: [1, 1, 1, 4, 2]
# Fitness 6
#
# Coordinates: [0, 4, 1, 4, 2]
# Fitness 9
#
# After Mutation
# Coordinates: [0, 1, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 3, 1, 4, 2]
# Fitness 10
#
# Coordinates: [1, 1, 1, 1, 2]
# Fitness 3
#
# Coordinates: [1, 4, 1, 4, 2]
# Fitness 7
#
# Generation 186
#
# After Crossover
# Coordinates: [0, 1, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 3, 1, 4, 2]
# Fitness 10
#
# Coordinates: [1, 4, 1, 4, 2]
# Fitness 7
#
# Coordinates: [0, 3, 1, 4, 2]
# Fitness 10
#
# After Mutation
# Coordinates: [0, 1, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 3, 1, 4, 2]
# Fitness 10
#
# Coordinates: [1, 4, 1, 4, 2]
# Fitness 7
#
# Coordinates: [2, 3, 1, 4, 2]
# Fitness 8
#
# Generation 187
#
# After Crossover
# Coordinates: [0, 1, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 3, 1, 4, 2]
# Fitness 10
#
# Coordinates: [2, 3, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 3, 1, 4, 2]
# Fitness 10
#
# After Mutation
# Coordinates: [0, 1, 1, 0, 2]
# Fitness 6
#
# Coordinates: [0, 3, 1, 4, 2]
# Fitness 10
#
# Coordinates: [2, 3, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 3, 1, 1, 2]
# Fitness 7
#
# Generation 188
#
# After Crossover
# Coordinates: [2, 3, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 3, 1, 4, 2]
# Fitness 10
#
# Coordinates: [0, 3, 1, 4, 2]
# Fitness 10
#
# Coordinates: [0, 3, 1, 1, 2]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 3, 1, 0, 2]
# Fitness 7
#
# Coordinates: [4, 3, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 3, 1, 3, 2]
# Fitness 7
#
# Coordinates: [0, 3, 2, 1, 2]
# Fitness 4
#
# Generation 189
#
# After Crossover
# Coordinates: [2, 3, 1, 4, 2]
# Fitness 8
#
# Coordinates: [4, 3, 1, 0, 2]
# Fitness 8
#
# Coordinates: [0, 3, 1, 4, 2]
# Fitness 10
#
# Coordinates: [4, 3, 1, 3, 2]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 3, 0, 4, 2]
# Fitness 6
#
# Coordinates: [4, 3, 1, 0, 0]
# Fitness 5
#
# Coordinates: [0, 1, 1, 4, 2]
# Fitness 8
#
# Coordinates: [4, 3, 1, 1, 2]
# Fitness 5
#
# Generation 190
#
# After Crossover
# Coordinates: [2, 3, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 1, 0, 4, 2]
# Fitness 6
#
# Coordinates: [4, 3, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 1, 1, 0, 0]
# Fitness 4
#
# After Mutation
# Coordinates: [2, 3, 1, 4, 4]
# Fitness 8
#
# Coordinates: [0, 1, 0, 4, 2]
# Fitness 6
#
# Coordinates: [4, 3, 1, 4, 0]
# Fitness 6
#
# Coordinates: [0, 1, 1, 2, 0]
# Fitness 6
#
# Generation 191
#
# After Crossover
# Coordinates: [0, 1, 1, 4, 4]
# Fitness 5
#
# Coordinates: [2, 3, 0, 4, 2]
# Fitness 6
#
# Coordinates: [4, 3, 1, 4, 4]
# Fitness 6
#
# Coordinates: [2, 3, 1, 4, 0]
# Fitness 8
#
# After Mutation
# Coordinates: [0, 1, 1, 4, 2]
# Fitness 8
#
# Coordinates: [2, 3, 0, 4, 0]
# Fitness 6
#
# Coordinates: [4, 3, 1, 4, 2]
# Fitness 8
#
# Coordinates: [2, 2, 1, 4, 0]
# Fitness 7
#
# Generation 192
#
# After Crossover
# Coordinates: [4, 3, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 1, 1, 4, 2]
# Fitness 8
#
# Coordinates: [2, 2, 1, 4, 2]
# Fitness 5
#
# Coordinates: [0, 1, 1, 4, 0]
# Fitness 7
#
# After Mutation
# Coordinates: [4, 2, 1, 4, 2]
# Fitness 6
#
# Coordinates: [0, 1, 1, 1, 2]
# Fitness 5
#
# Coordinates: [2, 4, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 1, 1, 0, 0]
# Fitness 4
#
# Generation 193
#
# After Crossover
# Coordinates: [4, 2, 1, 4, 2]
# Fitness 6
#
# Coordinates: [2, 4, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 1, 1, 4, 2]
# Fitness 8
#
# Coordinates: [2, 4, 1, 1, 2]
# Fitness 7
#
# After Mutation
# Coordinates: [4, 2, 1, 4, 2]
# Fitness 6
#
# Coordinates: [2, 4, 4, 4, 2]
# Fitness 4
#
# Coordinates: [0, 1, 0, 4, 2]
# Fitness 6
#
# Coordinates: [2, 4, 1, 1, 3]
# Fitness 8
#
# Generation 194
#
# After Crossover
# Coordinates: [4, 2, 1, 1, 3]
# Fitness 6
#
# Coordinates: [2, 4, 1, 4, 2]
# Fitness 8
#
# Coordinates: [0, 1, 1, 1, 3]
# Fitness 5
#
# Coordinates: [2, 4, 0, 4, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [4, 2, 4, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 2, 4, 2]
# Fitness 6
#
# Coordinates: [0, 1, 2, 1, 3]
# Fitness 5
#
# Coordinates: [3, 4, 0, 4, 2]
# Fitness 7
#
# Generation 195
#
# After Crossover
# Coordinates: [3, 4, 0, 1, 3]
# Fitness 7
#
# Coordinates: [4, 2, 4, 4, 2]
# Fitness 4
#
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [4, 2, 2, 4, 2]
# Fitness 4
#
# After Mutation
# Coordinates: [3, 4, 0, 1, 3]
# Fitness 7
#
# Coordinates: [4, 2, 4, 4, 2]
# Fitness 4
#
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [4, 3, 2, 4, 2]
# Fitness 5
#
# Generation 196
#
# After Crossover
# Coordinates: [3, 4, 4, 1, 3]
# Fitness 7
#
# Coordinates: [2, 4, 0, 1, 3]
# Fitness 8
#
# Coordinates: [4, 3, 4, 1, 3]
# Fitness 4
#
# Coordinates: [2, 4, 2, 4, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [3, 4, 3, 1, 3]
# Fitness 5
#
# Coordinates: [2, 3, 0, 1, 3]
# Fitness 5
#
# Coordinates: [4, 3, 4, 1, 3]
# Fitness 4
#
# Coordinates: [2, 4, 2, 4, 2]
# Fitness 6
#
# Generation 197
#
# After Crossover
# Coordinates: [3, 4, 2, 4, 2]
# Fitness 7
#
# Coordinates: [2, 4, 3, 1, 3]
# Fitness 8
#
# Coordinates: [2, 3, 0, 4, 2]
# Fitness 6
#
# Coordinates: [2, 4, 2, 1, 3]
# Fitness 8
#
# After Mutation
# Coordinates: [3, 4, 2, 2, 2]
# Fitness 5
#
# Coordinates: [2, 4, 3, 1, 3]
# Fitness 8
#
# Coordinates: [2, 3, 0, 2, 2]
# Fitness 4
#
# Coordinates: [2, 4, 1, 1, 3]
# Fitness 8
#
# Generation 198
#
# After Crossover
# Coordinates: [2, 4, 3, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 1, 1, 3]
# Fitness 8
#
# Coordinates: [3, 4, 3, 1, 3]
# Fitness 5
#
# Coordinates: [2, 4, 2, 2, 2]
# Fitness 3
#
# After Mutation
# Coordinates: [2, 4, 3, 2, 3]
# Fitness 4
#
# Coordinates: [2, 4, 1, 1, 1]
# Fitness 6
#
# Coordinates: [2, 4, 3, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 2, 4, 2]
# Fitness 6
#
# Generation 199
#
# After Crossover
# Coordinates: [2, 4, 1, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 3, 1, 1]
# Fitness 6
#
# Coordinates: [2, 4, 2, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 3, 4, 2]
# Fitness 6
#
# After Mutation
# Coordinates: [2, 4, 1, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 3, 1, 4]
# Fitness 8
#
# Coordinates: [2, 0, 2, 1, 3]
# Fitness 7
#
# Coordinates: [2, 4, 2, 4, 2]
# Fitness 6
#
# Generation 200
#
# After Crossover
# Coordinates: [2, 4, 1, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 3, 1, 4]
# Fitness 8
#
# Coordinates: [2, 0, 1, 1, 3]
# Fitness 6
#
# Coordinates: [2, 4, 2, 1, 3]
# Fitness 8
#
# After Mutation
# Coordinates: [2, 4, 1, 1, 3]
# Fitness 8
#
# Coordinates: [3, 4, 3, 1, 4]
# Fitness 6
#
# Coordinates: [2, 4, 1, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 2, 2, 3]
# Fitness 5
#
# Generation 201
#
# After Crossover
# Coordinates: [2, 4, 1, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 1, 1, 3]
# Fitness 8
#
# Coordinates: [3, 4, 3, 1, 3]
# Fitness 5
#
# Coordinates: [2, 4, 1, 1, 4]
# Fitness 8
#
# After Mutation
# Coordinates: [2, 4, 3, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 1, 2, 3]
# Fitness 5
#
# Coordinates: [3, 4, 3, 1, 1]
# Fitness 4
#
# Coordinates: [2, 4, 1, 1, 0]
# Fitness 8
#
# Generation 202
#
# After Crossover
# Coordinates: [2, 4, 1, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 3, 1, 0]
# Fitness 8
#
# Coordinates: [2, 4, 3, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 1, 2, 3]
# Fitness 5
#
# After Mutation
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 3, 1, 0]
# Fitness 8
#
# Coordinates: [2, 4, 3, 1, 3]
# Fitness 8
#
# Coordinates: [2, 1, 1, 2, 3]
# Fitness 4
#
# Generation 203
#
# After Crossover
# Coordinates: [2, 4, 3, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 4, 1, 0]
# Fitness 7
#
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 3, 1, 3]
# Fitness 8
#
# After Mutation
# Coordinates: [2, 4, 3, 1, 2]
# Fitness 7
#
# Coordinates: [2, 4, 4, 1, 0]
# Fitness 7
#
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [4, 4, 3, 1, 3]
# Fitness 6
#
# Generation 204
#
# After Crossover
# Coordinates: [2, 4, 3, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 4, 1, 2]
# Fitness 5
#
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 4, 1, 0]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 2, 3, 1, 3]
# Fitness 7
#
# Coordinates: [2, 3, 4, 1, 2]
# Fitness 3
#
# Coordinates: [4, 4, 4, 1, 3]
# Fitness 6
#
# Coordinates: [2, 4, 4, 1, 1]
# Fitness 6
#
# Generation 205
#
# After Crossover
# Coordinates: [4, 4, 3, 1, 3]
# Fitness 6
#
# Coordinates: [2, 2, 4, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [2, 2, 3, 1, 1]
# Fitness 6
#
# After Mutation
# Coordinates: [4, 4, 4, 1, 3]
# Fitness 6
#
# Coordinates: [2, 2, 4, 2, 3]
# Fitness 5
#
# Coordinates: [2, 4, 4, 3, 3]
# Fitness 6
#
# Coordinates: [2, 4, 3, 1, 1]
# Fitness 6
#
# Generation 206
#
# After Crossover
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [4, 4, 4, 3, 3]
# Fitness 5
#
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [4, 4, 3, 1, 1]
# Fitness 4
#
# After Mutation
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [0, 4, 4, 3, 3]
# Fitness 6
#
# Coordinates: [2, 4, 4, 2, 3]
# Fitness 5
#
# Coordinates: [4, 3, 3, 1, 1]
# Fitness 4
#
# Generation 207
#
# After Crossover
# Coordinates: [0, 4, 4, 1, 3]
# Fitness 9
#
# Coordinates: [2, 4, 4, 3, 3]
# Fitness 6
#
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 4, 2, 3]
# Fitness 5
#
# After Mutation
# Coordinates: [0, 4, 2, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 4, 4, 3]
# Fitness 5
#
# Coordinates: [2, 4, 4, 4, 3]
# Fitness 5
#
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Generation 208
#
# After Crossover
# Coordinates: [2, 4, 2, 1, 3]
# Fitness 8
#
# Coordinates: [0, 4, 4, 1, 3]
# Fitness 9
#
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [0, 4, 2, 4, 3]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 4, 2, 1, 4]
# Fitness 6
#
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [2, 4, 2, 4, 3]
# Fitness 7
#
# Generation 209
#
# After Crossover
# Coordinates: [2, 4, 4, 1, 3]
# Fitness 8
#
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Coordinates: [2, 4, 2, 1, 3]
# Fitness 8
#
# Coordinates: [0, 2, 4, 4, 3]
# Fitness 7
#
# After Mutation
# Coordinates: [2, 3, 4, 1, 3]
# Fitness 5
#
# Coordinates: [0, 2, 4, 4, 3]
# Fitness 7
#
# Coordinates: [3, 4, 2, 1, 3]
# Fitness 7
#
# Coordinates: [4, 2, 4, 4, 3]
# Fitness 5
#
# Generation 210
#
# After Crossover
# Coordinates: [3, 4, 4, 4, 3]
# Fitness 4
#
# Coordinates: [0, 2, 2, 1, 3]
# Fitness 7
#
# Coordinates: [2, 3, 4, 4, 3]
# Fitness 4
#
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# After Mutation
# Coordinates: [3, 4, 4, 4, 1]
# Fitness 5
#
# Coordinates: [4, 2, 2, 1, 3]
# Fitness 6
#
# Coordinates: [2, 3, 2, 4, 3]
# Fitness 5
#
# Coordinates: [0, 2, 4, 2, 3]
# Fitness 8
#
# Generation 211
#
# After Crossover
# Coordinates: [4, 2, 2, 2, 3]
# Fitness 5
#
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Coordinates: [3, 4, 4, 2, 3]
# Fitness 5
#
# Coordinates: [0, 2, 4, 4, 1]
# Fitness 8
#
# After Mutation
# Coordinates: [4, 2, 2, 2, 3]
# Fitness 5
#
# Coordinates: [0, 4, 4, 1, 3]
# Fitness 9
#
# Coordinates: [3, 4, 4, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 4, 4, 3]
# Fitness 7
#
# Generation 212
#
# After Crossover
# Coordinates: [3, 4, 4, 1, 3]
# Fitness 7
#
# Coordinates: [0, 4, 4, 1, 3]
# Fitness 9
#
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Coordinates: [0, 4, 4, 4, 3]
# Fitness 6
#
# After Mutation
# Coordinates: [3, 4, 4, 1, 2]
# Fitness 6
#
# Coordinates: [0, 1, 4, 1, 3]
# Fitness 8
#
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Coordinates: [0, 4, 4, 4, 3]
# Fitness 6
#
# Generation 213
#
# After Crossover
# Coordinates: [0, 1, 4, 1, 3]
# Fitness 8
#
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Coordinates: [3, 4, 4, 1, 3]
# Fitness 7
#
# Coordinates: [0, 2, 4, 1, 2]
# Fitness 7
#
# After Mutation
# Coordinates: [0, 1, 4, 0, 3]
# Fitness 8
#
# Coordinates: [0, 2, 4, 3, 3]
# Fitness 7
#
# Coordinates: [4, 4, 4, 1, 3]
# Fitness 6
#
# Coordinates: [0, 2, 4, 1, 0]
# Fitness 8
#
# Generation 214
#
# After Crossover
# Coordinates: [0, 2, 4, 0, 3]
# Fitness 8
#
# Coordinates: [0, 1, 4, 1, 0]
# Fitness 6
#
# Coordinates: [0, 2, 4, 0, 3]
# Fitness 8
#
# Coordinates: [0, 1, 4, 3, 3]
# Fitness 5
#
# After Mutation
# Coordinates: [0, 2, 4, 0, 0]
# Fitness 6
#
# Coordinates: [2, 1, 4, 1, 0]
# Fitness 6
#
# Coordinates: [0, 2, 4, 2, 3]
# Fitness 8
#
# Coordinates: [0, 1, 0, 3, 3]
# Fitness 4
#
# Generation 215
#
# After Crossover
# Coordinates: [0, 2, 4, 2, 3]
# Fitness 8
#
# Coordinates: [0, 2, 4, 0, 0]
# Fitness 6
#
# Coordinates: [2, 1, 4, 2, 3]
# Fitness 6
#
# Coordinates: [0, 2, 4, 1, 0]
# Fitness 8
#
# After Mutation
# Coordinates: [1, 2, 4, 2, 3]
# Fitness 7
#
# Coordinates: [0, 2, 4, 4, 0]
# Fitness 7
#
# Coordinates: [2, 1, 4, 2, 2]
# Fitness 4
#
# Coordinates: [0, 2, 4, 3, 0]
# Fitness 7
#
# Generation 216
#
# After Crossover
# Coordinates: [0, 2, 4, 2, 3]
# Fitness 8
#
# Coordinates: [1, 2, 4, 4, 0]
# Fitness 6
#
# Coordinates: [0, 2, 4, 2, 3]
# Fitness 8
#
# Coordinates: [1, 2, 4, 3, 0]
# Fitness 8
#
# After Mutation
# Coordinates: [0, 2, 1, 2, 3]
# Fitness 5
#
# Coordinates: [1, 2, 4, 4, 0]
# Fitness 6
#
# Coordinates: [0, 2, 4, 2, 3]
# Fitness 8
#
# Coordinates: [1, 2, 1, 3, 0]
# Fitness 7
#
# Generation 217
#
# After Crossover
# Coordinates: [1, 2, 4, 2, 3]
# Fitness 7
#
# Coordinates: [0, 2, 1, 3, 0]
# Fitness 7
#
# Coordinates: [1, 2, 4, 2, 3]
# Fitness 7
#
# Coordinates: [0, 2, 4, 4, 0]
# Fitness 7
#
# After Mutation
# Coordinates: [0, 2, 4, 2, 3]
# Fitness 8
#
# Coordinates: [0, 2, 1, 3, 2]
# Fitness 6
#
# Coordinates: [1, 0, 4, 2, 3]
# Fitness 6
#
# Coordinates: [0, 4, 4, 4, 0]
# Fitness 6
#
# Generation 218
#
# After Crossover
# Coordinates: [0, 2, 4, 2, 3]
# Fitness 8
#
# Coordinates: [0, 2, 1, 3, 2]
# Fitness 6
#
# Coordinates: [1, 0, 4, 2, 3]
# Fitness 6
#
# Coordinates: [0, 2, 4, 2, 3]
# Fitness 8
#
# After Mutation
# Coordinates: [2, 2, 4, 2, 3]
# Fitness 5
#
# Coordinates: [0, 2, 1, 2, 2]
# Fitness 5
#
# Coordinates: [1, 0, 1, 2, 3]
# Fitness 2
#
# Coordinates: [3, 2, 4, 2, 3]
# Fitness 6
#
# Generation 219
#
# After Crossover
# Coordinates: [2, 2, 4, 2, 3]
# Fitness 5
#
# Coordinates: [3, 2, 4, 2, 3]
# Fitness 6
#
# Coordinates: [0, 2, 1, 2, 3]
# Fitness 5
#
# Coordinates: [3, 2, 4, 2, 2]
# Fitness 5
#
# After Mutation
# Coordinates: [2, 2, 2, 2, 3]
# Fitness 3
#
# Coordinates: [3, 2, 4, 2, 3]
# Fitness 6
#
# Coordinates: [0, 4, 1, 2, 3]
# Fitness 6
#
# Coordinates: [3, 2, 4, 2, 2]
# Fitness 5
#
# Generation 220
#
# After Crossover
# Coordinates: [0, 4, 4, 2, 3]
# Fitness 7
#
# Coordinates: [3, 2, 1, 2, 3]
# Fitness 2
#
# Coordinates: [3, 2, 4, 2, 3]
# Fitness 6
#
# Coordinates: [3, 2, 4, 2, 2]
# Fitness 5
#
# After Mutation
# Coordinates: [3, 4, 4, 2, 3]
# Fitness 5
#
# Coordinates: [3, 2, 1, 0, 3]
# Fitness 2
#
# Coordinates: [3, 3, 4, 2, 3]
# Fitness 5
#
# Coordinates: [3, 2, 4, 2, 2]
# Fitness 5
#
# Generation 221
#
# After Crossover
# Coordinates: [3, 3, 4, 2, 3]
# Fitness 5
#
# Coordinates: [3, 4, 4, 2, 3]
# Fitness 5
#
# Coordinates: [3, 2, 4, 2, 3]
# Fitness 6
#
# Coordinates: [3, 4, 4, 2, 2]
# Fitness 5
#
# After Mutation
# Coordinates: [3, 3, 4, 2, 0]
# Fitness 7
#
# Coordinates: [0, 4, 4, 2, 3]
# Fitness 7
#
# Coordinates: [3, 2, 4, 4, 3]
# Fitness 5
#
# Coordinates: [3, 4, 0, 2, 2]
# Fitness 6
#
# Generation 222
#
# After Crossover
# Coordinates: [0, 4, 4, 2, 0]
# Fitness 7
#
# Coordinates: [3, 3, 4, 2, 3]
# Fitness 5
#
# Coordinates: [3, 4, 4, 2, 0]
# Fitness 7
#
# Coordinates: [3, 3, 0, 2, 2]
# Fitness 7
#
# After Mutation
# Coordinates: [0, 2, 4, 2, 0]
# Fitness 8
#
# Coordinates: [3, 0, 4, 2, 3]
# Fitness 6
#
# Coordinates: [3, 2, 4, 2, 0]
# Fitness 8
#
# Coordinates: [3, 3, 0, 2, 2]
# Fitness 7
#
# Generation 223
#
# After Crossover
# Coordinates: [3, 2, 4, 2, 0]
# Fitness 8
#
# Coordinates: [0, 2, 4, 2, 0]
# Fitness 8
#
# Coordinates: [3, 3, 4, 2, 0]
# Fitness 7
#
# Coordinates: [0, 2, 0, 2, 2]
# Fitness 5
#
# After Mutation
# Coordinates: [3, 2, 4, 2, 0]
# Fitness 8
#
# Coordinates: [0, 2, 4, 3, 0]
# Fitness 7
#
# Coordinates: [3, 3, 4, 0, 0]
# Fitness 5
#
# Coordinates: [1, 2, 0, 2, 2]
# Fitness 5
#
# Generation 224
#
# After Crossover
# Coordinates: [0, 2, 4, 2, 0]
# Fitness 8
#
# Coordinates: [3, 2, 4, 3, 0]
# Fitness 7
#
# Coordinates: [3, 3, 4, 2, 0]
# Fitness 7
#
# Coordinates: [3, 2, 4, 0, 0]
# Fitness 6
#
# After Mutation
# Coordinates: [0, 2, 4, 2, 3]
# Fitness 8
#
# Coordinates: [3, 2, 4, 4, 0]
# Fitness 7
#
# Coordinates: [3, 3, 4, 2, 4]
# Fitness 7
#
# Coordinates: [1, 2, 4, 0, 0]
# Fitness 7
#
# Generation 225
#
# After Crossover
# Coordinates: [3, 2, 4, 2, 3]
# Fitness 6
#
# Coordinates: [0, 2, 4, 4, 0]
# Fitness 7
#
# Coordinates: [3, 3, 4, 2, 3]
# Fitness 5
#
# Coordinates: [0, 2, 4, 2, 4]
# Fitness 7
#
# After Mutation
# Coordinates: [3, 2, 4, 1, 3]
# Fitness 8
#
# Coordinates: [0, 2, 4, 2, 0]
# Fitness 8
#
# Coordinates: [3, 3, 4, 1, 3]
# Fitness 5
#
# Coordinates: [0, 2, 1, 2, 4]
# Fitness 6
#
# Generation 226
#
# After Crossover
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Coordinates: [3, 2, 4, 2, 0]
# Fitness 8
#
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Coordinates: [3, 2, 1, 2, 4]
# Fitness 5
#
# After Mutation
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Coordinates: [3, 1, 4, 2, 0]
# Fitness 10
#
# Coordinates: [0, 2, 4, 1, 3]
# Fitness 10
#
# Coordinates: [3, 2, 1, 2, 4]
# Fitness 5
#
# Generation 226
# Ideal State Reached!
# Coordinates: [(0, 0), (1, 2), (2, 4), (3, 1), (4, 3)]
# Attacking pairs: [0, 0, 0, 0, 0]
# ['Q', 'X', 'X', 'X', 'X']
# ['X', 'X', 'X', 'Q', 'X']
# ['X', 'Q', 'X', 'X', 'X']
# ['X', 'X', 'X', 'X', 'Q']
# ['X', 'X', 'Q', 'X', 'X']
